# %%
import os,sys
import random
import pandas as pd
import numpy as np
import seaborn as sns

import tensorflow as tf
import matplotlib as plt
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error, r2_score

# %%
### Enter the data folder name and WCR information

# Load the data folder path
path = os.getcwd()
path_upper = path + '/data_mortar'

# WCR information
WC_name_tag = [40, 42.5, 45, 47.5, 50, 52.5, 55, 57.5, 60]

# Fit the random seed
seed_data = 4885
random.seed(seed_data)
np.random.seed(seed_data)
os.environ["PYTHONHASHSEED"] = str(seed_data)
tf.random.set_seed(seed_data)

# Set the name of the training model file to save.
last_model_save_name = "WCRnet_ResNet_34_layers.h5"
last_model_save_dir = path + f'/save_models/{last_model_save_name}'

# Layer paramter for WCRnet (ResNet)
layer_list = [3, 4, 6, 3]

# Parameter for Training
epochs = 1000                 # training epochs
batch_sizes = 1024            # batch size
initial_learning_rate = 0.01   # initial learning rate
input_shape = 6               # input shape of the model

# Parameter for K-FOLD validation
k_fold_num = 4                # number of K-Folds
current_fold = 0              # Set the 'K' : 0 | 1 | 2 | 3

# %%
### Data normalization

# Normalize to the minimum and maximum sensor measurement values.
def sense_min_max_Normalization(input_data, min_value, max_value):
    data = (input_data - min_value) / (max_value - min_value) 
    
    return data

def data_set_normalization(data):
    # sensor_min_value
    vwc_min = 0
    ec_min = 0
    salinity_min = 0
    tds_min = 0
    epsilon_min = 0
    temp_min = -40
    
    # sensor_max_value
    vwc_max = 100
    ec_max = 20000
    salinity_max = 20000
    tds_max = 20000
    temp_max = 80
    epsilon_max = 82
    
    # sensor_normalization 
    data['TEMP'] = sense_min_max_Normalization(data['TEMP'],temp_min,temp_max)
    data['EC'] = sense_min_max_Normalization(data['EC'],ec_min,ec_max)
    data['VWC'] = sense_min_max_Normalization(data['VWC'],vwc_min,vwc_max)
    data['TDS'] = sense_min_max_Normalization(data['TDS'],tds_min,tds_max)
    data['SALINITY'] = sense_min_max_Normalization(data['SALINITY'],salinity_min,salinity_max)
    data['EPSILON'] = sense_min_max_Normalization(data['EPSILON'],epsilon_min,epsilon_max)
    
    return data

# %%
### Load FDR Data

path_list = []
path_under=os.listdir(path_upper)

# Load data_path
for i in range(len(path_under)): # collect under directory file path
    path_sub=os.listdir(path_upper+'/'+path_under[i])
    
    for j in range(len(path_sub)):
        path_list.append(path_upper+'/'+path_under[i]+'/'+path_sub[j])

# Create the zero matrix
data_list = [0]*len(path_list)
rand_x_data_list = [0]*len(path_list)
rand_y_data_list = [0]*len(path_list)

# Load data_value
for i,j in enumerate(path_list):
    data_list[i] =pd.read_csv(j)
    data_list[i] = data_set_normalization(data_list[i])

# Create the entire dataset.
total_data = pd.concat(data_list)
total_data = total_data.dropna()

# Print the data format
total_data
# Out:
#      WC_ratio      TEMP       EC     VWC      TDS  SALINITY   EPSILON
# 0         0.4  0.523083  0.18250  0.6175  0.09125   0.10035  0.690366
# 1         0.4  0.520667  0.18320  0.6234  0.09160   0.10075  0.698902
# 2         0.4  0.519000  0.18435  0.6234  0.09215   0.10135  0.698902
# 3         0.4  0.517917  0.18755  0.6278  0.09375   0.10315  0.705244
# 4         0.4  0.517000  0.18830  0.6326  0.09415   0.10355  0.711829
# ..        ...       ...      ...     ...      ...       ...       ...
# 526       0.6  0.487667  0.29310  0.9488  0.14655   0.16120  0.967439
# 527       0.6  0.487667  0.29355  0.9488  0.14675   0.16145  0.967439
# 528       0.6  0.487667  0.29400  0.9488  0.14700   0.16170  0.967439
# 529       0.6  0.487667  0.29355  0.9488  0.14675   0.16145  0.967439
# 530       0.6  0.487667  0.29355  0.9488  0.14675   0.16145  0.967439
#
# [23350 rows x 7 columns]

# %%
# GT-label (WCR)
y_R = round(total_data['WC_ratio']*100, 1)
y_data_total = y_R.to_numpy()

# FDR sensor data
x_R = total_data[['TEMP','VWC','EPSILON','SALINITY','TDS','EC']]
x_data_total = x_R.to_numpy()

# %%
# split train/test data
tmp_x_train, x_test, tmp_y_train, y_test = train_test_split(x_data_total.astype('float'), y_data_total.astype('float'), test_size=0.2, random_state=seed_data)

# splot train/valid data
x_train_kfold = []
x_valid_kfold = []
y_train_kfold = []
y_valid_kfold = []

kfold = KFold(n_splits=k_fold_num)

for train_idx, valid_idx in kfold.split(tmp_x_train):
    x_train_kfold.append(tmp_x_train[train_idx])
    x_valid_kfold.append(tmp_x_train[valid_idx])
    y_train_kfold.append(tmp_y_train[train_idx])
    y_valid_kfold.append(tmp_y_train[valid_idx])

# Print the quantity of data
print(f"quantity of train data : {len(x_train_kfold[0])}")
print(f"quantity of validation data : {len(x_valid_kfold[0])}")
print(f"quantity of test data : {len(y_test)}")
# Out:
# quantity of train data : 14010
# quantity of validation data : 4670
# quantity of test data : 4670

# %%
### Create WCRnet (ResNet)

print("tf_version : %s" %tf.__version__)

def layer_1(x):    
    x = tf.keras.layers.Dense(32, kernel_initializer='normal')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
 
    return x   
 
    
def layer_2(x):       
 
    for i in range(layer_list[0]): 
        if i==0: 
            # upsample 32 -> 64
            reshaped_input = tf.expand_dims(x, axis=-1)
            upsampled_output = tf.keras.layers.UpSampling1D(size=2)(reshaped_input)
            shortcut = tf.squeeze(upsampled_output, axis=-1)            
        else:
            shortcut = x
            
        x = tf.keras.layers.Dense(64, kernel_initializer='normal')(x)     
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)
        
        x = tf.keras.layers.Dense(64, kernel_initializer='normal')(x)     
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)
        
        x = tf.keras.layers.Add()([x, shortcut])
        x = tf.keras.activations.relu(x)

        shortcut = x
      
    return x
 
  
def layer_3(x):        
    
    for i in range(layer_list[1]):  
        if i==0: 
            # upsample 64 -> 128
            reshaped_input = tf.expand_dims(x, axis=-1)
            upsampled_output = tf.keras.layers.UpSampling1D(size=2)(reshaped_input)
            shortcut = tf.squeeze(upsampled_output, axis=-1)
        else:
            shortcut = x
            
        x = tf.keras.layers.Dense(128, kernel_initializer='normal')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)
    
        x = tf.keras.layers.Dense(128, kernel_initializer='normal')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)  

        x = tf.keras.layers.Add()([x, shortcut])
        x = tf.keras.activations.relu(x)

        shortcut = x      
            
    return x
 
  
def layer_4(x):   
    
    for i in range(layer_list[2]): 
        if i==0: 
            # downsample 128 -> 64
            reshaped_input = tf.expand_dims(x, axis=-1)
            downsampled_output  = tf.keras.layers.UpSampling1D(size=2)(reshaped_input)
            shortcut = tf.squeeze(downsampled_output , axis=-1)
        else:
            shortcut = x
            
        x = tf.keras.layers.Dense(256, kernel_initializer='normal')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)
    
        x = tf.keras.layers.Dense(256, kernel_initializer='normal')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)  

        x = tf.keras.layers.Add()([x, shortcut])
        x = tf.keras.activations.relu(x)

        shortcut = x      
            
    return x
 
  
def layer_5(x):
    
    for i in range(layer_list[3]):
        if i==0: 
            # downsample 64 -> 32
            reshaped_input = tf.expand_dims(x, axis=-1)
            downsampled_output  = tf.keras.layers.UpSampling1D(size=2)(reshaped_input)
            shortcut = tf.squeeze(downsampled_output , axis=-1)
        else:
            shortcut = x    

        x = tf.keras.layers.Dense(512, kernel_initializer='normal')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)
    
        x = tf.keras.layers.Dense(512, kernel_initializer='normal')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)  

        x = tf.keras.layers.Add()([x, shortcut])
        x = tf.keras.activations.relu(x)

        shortcut = x      
            
    return x

# Learning rate scheduler
def lr_exp_decay(epoch, lr):
    if epoch <50:
        return initial_learning_rate
    
    elif epoch >=50 and epoch <100:
        return initial_learning_rate * 0.1
    
    elif epoch >=100 and epoch <300:
        return initial_learning_rate * 0.01
    
    elif epoch >=300 and epoch <500:
        return initial_learning_rate * 0.001
    
    else:
        return initial_learning_rate * 0.0001
# Out:
# tf_version : 2.6.2

# %%
### Compile WCRnet (ResNet)

input_tensor =  tf.keras.Input(shape=(input_shape,))

x = layer_1(input_tensor)
x = layer_2(x)
x = layer_3(x)
x = layer_4(x)
x = layer_5(x)
 
output_tensor = tf.keras.layers.Dense(1, kernel_initializer='normal')(x)
output_tensor = tf.keras.activations.relu(output_tensor)

model = tf.keras.Model(input_tensor, output_tensor)
model.summary()

start_model=model.get_weights()
counter  = 0
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           224         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32)           128         dense[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu (TFOpLambda)         (None, 32)           0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           2112        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64)           256         dense_1[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_1 (TFOpLambda)       (None, 64)           0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           4160        tf.nn.relu_1[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims (TFOpLambda)     (None, 32, 1)        0           tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# up_sampling1d (UpSampling1D)    (None, 64, 1)        0           tf.expand_dims[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_2 (TFOpLambda)       (None, 64)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.squeeze (TFOpLambd (None, 64)           0           up_sampling1d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64)           0           tf.nn.relu_2[0][0]
#                                                                  tf.compat.v1.squeeze[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_3 (TFOpLambda)       (None, 64)           0           add[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           4160        tf.nn.relu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_4 (TFOpLambda)       (None, 64)           0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           4160        tf.nn.relu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64)           256         dense_4[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_5 (TFOpLambda)       (None, 64)           0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64)           0           tf.nn.relu_5[0][0]
#                                                                  tf.nn.relu_3[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_6 (TFOpLambda)       (None, 64)           0           add_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           4160        tf.nn.relu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64)           256         dense_5[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_7 (TFOpLambda)       (None, 64)           0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           4160        tf.nn.relu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64)           256         dense_6[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_8 (TFOpLambda)       (None, 64)           0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64)           0           tf.nn.relu_8[0][0]
#                                                                  tf.nn.relu_6[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_9 (TFOpLambda)       (None, 64)           0           add_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          8320        tf.nn.relu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128)          512         dense_7[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_10 (TFOpLambda)      (None, 128)          0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          16512       tf.nn.relu_10[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_1 (TFOpLambda)   (None, 64, 1)        0           tf.nn.relu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 128)          512         dense_8[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_1 (UpSampling1D)  (None, 128, 1)       0           tf.expand_dims_1[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_11 (TFOpLambda)      (None, 128)          0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.squeeze_1 (TFOpLam (None, 128)          0           up_sampling1d_1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128)          0           tf.nn.relu_11[0][0]
#                                                                  tf.compat.v1.squeeze_1[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_12 (TFOpLambda)      (None, 128)          0           add_3[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 128)          16512       tf.nn.relu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 128)          512         dense_9[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_13 (TFOpLambda)      (None, 128)          0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 128)          16512       tf.nn.relu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128)          512         dense_10[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_14 (TFOpLambda)      (None, 128)          0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128)          0           tf.nn.relu_14[0][0]
#                                                                  tf.nn.relu_12[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_15 (TFOpLambda)      (None, 128)          0           add_4[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 128)          16512       tf.nn.relu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128)          512         dense_11[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_16 (TFOpLambda)      (None, 128)          0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 128)          16512       tf.nn.relu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 128)          512         dense_12[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_17 (TFOpLambda)      (None, 128)          0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 128)          0           tf.nn.relu_17[0][0]
#                                                                  tf.nn.relu_15[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_18 (TFOpLambda)      (None, 128)          0           add_5[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 128)          16512       tf.nn.relu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 128)          512         dense_13[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_19 (TFOpLambda)      (None, 128)          0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 128)          16512       tf.nn.relu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128)          512         dense_14[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_20 (TFOpLambda)      (None, 128)          0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 128)          0           tf.nn.relu_20[0][0]
#                                                                  tf.nn.relu_18[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_21 (TFOpLambda)      (None, 128)          0           add_6[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 256)          33024       tf.nn.relu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 256)          1024        dense_15[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_22 (TFOpLambda)      (None, 256)          0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 256)          65792       tf.nn.relu_22[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_2 (TFOpLambda)   (None, 128, 1)       0           tf.nn.relu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 256)          1024        dense_16[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_2 (UpSampling1D)  (None, 256, 1)       0           tf.expand_dims_2[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_23 (TFOpLambda)      (None, 256)          0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.squeeze_2 (TFOpLam (None, 256)          0           up_sampling1d_2[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 256)          0           tf.nn.relu_23[0][0]
#                                                                  tf.compat.v1.squeeze_2[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_24 (TFOpLambda)      (None, 256)          0           add_7[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 256)          65792       tf.nn.relu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 256)          1024        dense_17[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_25 (TFOpLambda)      (None, 256)          0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 256)          65792       tf.nn.relu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 256)          1024        dense_18[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_26 (TFOpLambda)      (None, 256)          0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 256)          0           tf.nn.relu_26[0][0]
#                                                                  tf.nn.relu_24[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_27 (TFOpLambda)      (None, 256)          0           add_8[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 256)          65792       tf.nn.relu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 256)          1024        dense_19[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_28 (TFOpLambda)      (None, 256)          0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 256)          65792       tf.nn.relu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 256)          1024        dense_20[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_29 (TFOpLambda)      (None, 256)          0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 256)          0           tf.nn.relu_29[0][0]
#                                                                  tf.nn.relu_27[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_30 (TFOpLambda)      (None, 256)          0           add_9[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 256)          65792       tf.nn.relu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 256)          1024        dense_21[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_31 (TFOpLambda)      (None, 256)          0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 256)          65792       tf.nn.relu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 256)          1024        dense_22[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_32 (TFOpLambda)      (None, 256)          0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 256)          0           tf.nn.relu_32[0][0]
#                                                                  tf.nn.relu_30[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_33 (TFOpLambda)      (None, 256)          0           add_10[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 256)          65792       tf.nn.relu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 256)          1024        dense_23[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_34 (TFOpLambda)      (None, 256)          0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 256)          65792       tf.nn.relu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 256)          1024        dense_24[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_35 (TFOpLambda)      (None, 256)          0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 256)          0           tf.nn.relu_35[0][0]
#                                                                  tf.nn.relu_33[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_36 (TFOpLambda)      (None, 256)          0           add_11[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 256)          65792       tf.nn.relu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 256)          1024        dense_25[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_37 (TFOpLambda)      (None, 256)          0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 256)          65792       tf.nn.relu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 256)          1024        dense_26[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_38 (TFOpLambda)      (None, 256)          0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 256)          0           tf.nn.relu_38[0][0]
#                                                                  tf.nn.relu_36[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_39 (TFOpLambda)      (None, 256)          0           add_12[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 512)          131584      tf.nn.relu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 512)          2048        dense_27[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_40 (TFOpLambda)      (None, 512)          0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 512)          262656      tf.nn.relu_40[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_3 (TFOpLambda)   (None, 256, 1)       0           tf.nn.relu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 512)          2048        dense_28[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_3 (UpSampling1D)  (None, 512, 1)       0           tf.expand_dims_3[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_41 (TFOpLambda)      (None, 512)          0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.squeeze_3 (TFOpLam (None, 512)          0           up_sampling1d_3[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 512)          0           tf.nn.relu_41[0][0]
#                                                                  tf.compat.v1.squeeze_3[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_42 (TFOpLambda)      (None, 512)          0           add_13[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 512)          262656      tf.nn.relu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 512)          2048        dense_29[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_43 (TFOpLambda)      (None, 512)          0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 512)          262656      tf.nn.relu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 512)          2048        dense_30[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_44 (TFOpLambda)      (None, 512)          0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 512)          0           tf.nn.relu_44[0][0]
#                                                                  tf.nn.relu_42[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_45 (TFOpLambda)      (None, 512)          0           add_14[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 512)          262656      tf.nn.relu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 512)          2048        dense_31[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_46 (TFOpLambda)      (None, 512)          0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 512)          262656      tf.nn.relu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 512)          2048        dense_32[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_47 (TFOpLambda)      (None, 512)          0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 512)          0           tf.nn.relu_47[0][0]
#                                                                  tf.nn.relu_45[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_48 (TFOpLambda)      (None, 512)          0           add_15[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 1)            513         tf.nn.relu_48[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_49 (TFOpLambda)      (None, 1)            0           dense_33[0][0]
# ==================================================================================================
# Total params: 2,379,489
# Trainable params: 2,364,321
# Non-trainable params: 15,168
# __________________________________________________________________________________________________

# %%
### Training WCRnet (ResNet)

train_mode = True

if train_mode == True:
    # Load the learning rate scheduler
    lr_s = tf.keras.callbacks.LearningRateScheduler(lr_exp_decay)

    # Load the Early Stopping
    early_stop = tf.keras.callbacks.EarlyStopping(patience=300, min_delta=3, monitor='val_loss')    
    
    # model compile
    model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam())

    # training
    history = model.fit(x_train_kfold[current_fold], y_train_kfold[current_fold], validation_data=(x_valid_kfold[current_fold], y_valid_kfold[current_fold]), epochs=epochs, batch_size=batch_sizes, callbacks=[lr_s, early_stop])

    # save the DL-R model
    model.save(last_model_save_dir)
# Out:
# Epoch 1/1000
# 14/14 [==============================] - 10s 144ms/step - loss: 281.6326 - val_loss: 2510.8750
# Epoch 2/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 4.9164 - val_loss: 1609.9052
# Epoch 3/1000
# 14/14 [==============================] - 1s 77ms/step - loss: 3.9405 - val_loss: 1210.6519
# Epoch 4/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 4.9828 - val_loss: 877.3395
# Epoch 5/1000
# 14/14 [==============================] - 1s 78ms/step - loss: 4.5129 - val_loss: 674.7969
# Epoch 6/1000
# 14/14 [==============================] - 1s 82ms/step - loss: 4.1830 - val_loss: 499.7951
# Epoch 7/1000
# 14/14 [==============================] - 1s 88ms/step - loss: 4.5081 - val_loss: 346.8095
# Epoch 8/1000
# 14/14 [==============================] - 1s 89ms/step - loss: 5.7171 - val_loss: 270.5243
# Epoch 9/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 4.7825 - val_loss: 248.1947
# Epoch 10/1000
# 14/14 [==============================] - 1s 85ms/step - loss: 4.2520 - val_loss: 213.6081
# Epoch 11/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 4.0090 - val_loss: 171.9600
# Epoch 12/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 4.5013 - val_loss: 106.9363
# Epoch 13/1000
# 14/14 [==============================] - 1s 70ms/step - loss: 6.6593 - val_loss: 134.3622
# Epoch 14/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 4.7867 - val_loss: 129.7434
# Epoch 15/1000
# 14/14 [==============================] - 1s 70ms/step - loss: 6.4200 - val_loss: 69.8345
# Epoch 16/1000
# 14/14 [==============================] - 1s 67ms/step - loss: 6.4010 - val_loss: 73.2467
# Epoch 17/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 5.9424 - val_loss: 100.2621
# Epoch 18/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 6.5198 - val_loss: 48.3564
# Epoch 19/1000
# 14/14 [==============================] - 1s 83ms/step - loss: 6.2919 - val_loss: 62.7609
# Epoch 20/1000
# 14/14 [==============================] - 1s 80ms/step - loss: 6.2397 - val_loss: 66.2597
# Epoch 21/1000
# 14/14 [==============================] - 1s 93ms/step - loss: 3.4209 - val_loss: 40.1656
# Epoch 22/1000
# 14/14 [==============================] - 1s 92ms/step - loss: 4.2680 - val_loss: 40.1018
# Epoch 23/1000
# 14/14 [==============================] - 1s 82ms/step - loss: 4.0534 - val_loss: 37.4258
# Epoch 24/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 3.8227 - val_loss: 37.1071
# Epoch 25/1000
# 14/14 [==============================] - 1s 90ms/step - loss: 6.9069 - val_loss: 71.7830
# Epoch 26/1000
# 14/14 [==============================] - 1s 70ms/step - loss: 5.4787 - val_loss: 72.5474
# Epoch 27/1000
# 14/14 [==============================] - 1s 68ms/step - loss: 3.0766 - val_loss: 87.2492
# Epoch 28/1000
# 14/14 [==============================] - 1s 68ms/step - loss: 2.9593 - val_loss: 68.0720
# Epoch 29/1000
# 14/14 [==============================] - 1s 82ms/step - loss: 3.4797 - val_loss: 59.3885
# Epoch 30/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 3.6765 - val_loss: 66.1380
# Epoch 31/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 5.9959 - val_loss: 80.6459
# Epoch 32/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 4.7702 - val_loss: 74.1878
# Epoch 33/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 4.5547 - val_loss: 70.4483
# Epoch 34/1000
# 14/14 [==============================] - 1s 87ms/step - loss: 4.7192 - val_loss: 77.0997
# Epoch 35/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 3.6741 - val_loss: 41.9353
# Epoch 36/1000
# 14/14 [==============================] - 1s 78ms/step - loss: 3.2167 - val_loss: 40.8581
# Epoch 37/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 4.4630 - val_loss: 53.5023
# Epoch 38/1000
# 14/14 [==============================] - 1s 77ms/step - loss: 4.1224 - val_loss: 64.3302
# Epoch 39/1000
# 14/14 [==============================] - 1s 83ms/step - loss: 3.4007 - val_loss: 28.1689
# Epoch 40/1000
# 14/14 [==============================] - 1s 88ms/step - loss: 4.1998 - val_loss: 28.1656
# Epoch 41/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 5.6368 - val_loss: 38.0887
# Epoch 42/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 8.4956 - val_loss: 119.5432
# Epoch 43/1000
# 14/14 [==============================] - 1s 70ms/step - loss: 5.3283 - val_loss: 114.1209
# Epoch 44/1000
# 14/14 [==============================] - 1s 67ms/step - loss: 4.1494 - val_loss: 68.9041
# Epoch 45/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 5.9413 - val_loss: 29.5158
# Epoch 46/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 4.5842 - val_loss: 23.3000
# Epoch 47/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 5.3682 - val_loss: 24.5293
# Epoch 48/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 4.4981 - val_loss: 34.4653
# Epoch 49/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 5.2456 - val_loss: 23.5194
# Epoch 50/1000
# 14/14 [==============================] - 1s 70ms/step - loss: 6.1946 - val_loss: 10.5846
# Epoch 51/1000
# 14/14 [==============================] - 1s 67ms/step - loss: 3.5982 - val_loss: 11.5059
# Epoch 52/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 3.3833 - val_loss: 15.8749
# Epoch 53/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 2.4931 - val_loss: 20.2075
# Epoch 54/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 2.8452 - val_loss: 22.2271
# Epoch 55/1000
# 14/14 [==============================] - 1s 68ms/step - loss: 2.3597 - val_loss: 22.9119
# Epoch 56/1000
# 14/14 [==============================] - 1s 70ms/step - loss: 2.3840 - val_loss: 22.2302
# Epoch 57/1000
# 14/14 [==============================] - 1s 68ms/step - loss: 2.1012 - val_loss: 21.0814
# Epoch 58/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 2.4184 - val_loss: 21.0851
# Epoch 59/1000
# 14/14 [==============================] - 1s 77ms/step - loss: 2.7962 - val_loss: 19.8042
# Epoch 60/1000
# 14/14 [==============================] - 1s 68ms/step - loss: 2.2010 - val_loss: 18.2426
# Epoch 61/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 2.2592 - val_loss: 16.6516
# Epoch 62/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 2.6369 - val_loss: 10.6248
# Epoch 63/1000
# 14/14 [==============================] - 1s 83ms/step - loss: 2.5769 - val_loss: 6.8339
# Epoch 64/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 2.3962 - val_loss: 8.1564
# Epoch 65/1000
# 14/14 [==============================] - 1s 77ms/step - loss: 2.3342 - val_loss: 8.6299
# Epoch 66/1000
# 14/14 [==============================] - 1s 85ms/step - loss: 2.2638 - val_loss: 7.8333
# Epoch 67/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 2.2348 - val_loss: 6.1959
# Epoch 68/1000
# 14/14 [==============================] - 1s 78ms/step - loss: 2.0761 - val_loss: 5.7324
# Epoch 69/1000
# 14/14 [==============================] - 1s 88ms/step - loss: 2.4587 - val_loss: 5.7728
# Epoch 70/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 2.4405 - val_loss: 7.6183
# Epoch 71/1000
# 14/14 [==============================] - 1s 89ms/step - loss: 2.4771 - val_loss: 8.0790
# Epoch 72/1000
# 14/14 [==============================] - 1s 82ms/step - loss: 2.1100 - val_loss: 5.6572
# Epoch 73/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 2.2574 - val_loss: 5.4549
# Epoch 74/1000
# 14/14 [==============================] - 1s 82ms/step - loss: 2.2618 - val_loss: 4.8070
# Epoch 75/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 2.2892 - val_loss: 3.0994
# Epoch 76/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 2.4028 - val_loss: 3.2086
# Epoch 77/1000
# 14/14 [==============================] - 1s 83ms/step - loss: 2.2031 - val_loss: 4.9279
# Epoch 78/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 2.4345 - val_loss: 4.3387
# Epoch 79/1000
# 14/14 [==============================] - 1s 89ms/step - loss: 2.1695 - val_loss: 8.2220
# Epoch 80/1000
# 14/14 [==============================] - 1s 89ms/step - loss: 2.2514 - val_loss: 4.3007
# Epoch 81/1000
# 14/14 [==============================] - 1s 87ms/step - loss: 2.2602 - val_loss: 6.8069
# Epoch 82/1000
# 14/14 [==============================] - 1s 78ms/step - loss: 2.3800 - val_loss: 7.7662
# Epoch 83/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 2.1249 - val_loss: 6.3356
# Epoch 84/1000
# 14/14 [==============================] - 1s 86ms/step - loss: 2.3517 - val_loss: 9.1111
# Epoch 85/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 2.3241 - val_loss: 13.9212
# Epoch 86/1000
# 14/14 [==============================] - 1s 87ms/step - loss: 2.2878 - val_loss: 11.2911
# Epoch 87/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 2.1238 - val_loss: 9.8441
# Epoch 88/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 2.1199 - val_loss: 25.5699
# Epoch 89/1000
# 14/14 [==============================] - 1s 85ms/step - loss: 2.1127 - val_loss: 38.5710
# Epoch 90/1000
# 14/14 [==============================] - 1s 85ms/step - loss: 2.2200 - val_loss: 44.9883
# Epoch 91/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 2.3812 - val_loss: 37.1144
# Epoch 92/1000
# 14/14 [==============================] - 1s 85ms/step - loss: 2.0341 - val_loss: 30.1096
# Epoch 93/1000
# 14/14 [==============================] - 1s 88ms/step - loss: 2.1170 - val_loss: 24.0094
# Epoch 94/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 1.8990 - val_loss: 16.3254
# Epoch 95/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 2.3066 - val_loss: 20.4330
# Epoch 96/1000
# 14/14 [==============================] - 1s 87ms/step - loss: 1.9631 - val_loss: 21.2673
# Epoch 97/1000
# 14/14 [==============================] - 1s 94ms/step - loss: 2.4726 - val_loss: 17.7912
# Epoch 98/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 2.0342 - val_loss: 14.7304
# Epoch 99/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 2.3939 - val_loss: 14.4632
# Epoch 100/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 2.1853 - val_loss: 13.0856
# Epoch 101/1000
# 14/14 [==============================] - 1s 67ms/step - loss: 1.8915 - val_loss: 9.5759
# Epoch 102/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 2.1311 - val_loss: 7.7340
# Epoch 103/1000
# 14/14 [==============================] - 1s 92ms/step - loss: 2.0632 - val_loss: 6.3466
# Epoch 104/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 1.7980 - val_loss: 5.3554
# Epoch 105/1000
# 14/14 [==============================] - 1s 83ms/step - loss: 1.8621 - val_loss: 4.1341
# Epoch 106/1000
# 14/14 [==============================] - 1s 90ms/step - loss: 1.8636 - val_loss: 3.4763
# Epoch 107/1000
# 14/14 [==============================] - 1s 90ms/step - loss: 1.8029 - val_loss: 3.2909
# Epoch 108/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 1.9833 - val_loss: 3.0428
# Epoch 109/1000
# 14/14 [==============================] - 1s 80ms/step - loss: 2.0914 - val_loss: 2.5601
# Epoch 110/1000
# 14/14 [==============================] - 1s 86ms/step - loss: 2.0387 - val_loss: 2.5400
# Epoch 111/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 2.1472 - val_loss: 2.4443
# Epoch 112/1000
# 14/14 [==============================] - 1s 77ms/step - loss: 2.0861 - val_loss: 2.0506
# Epoch 113/1000
# 14/14 [==============================] - 1s 90ms/step - loss: 1.9633 - val_loss: 1.8453
# Epoch 114/1000
# 14/14 [==============================] - 1s 77ms/step - loss: 1.8913 - val_loss: 1.7433
# Epoch 115/1000
# 14/14 [==============================] - 1s 78ms/step - loss: 2.0629 - val_loss: 1.6894
# Epoch 116/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 1.9937 - val_loss: 1.6683
# Epoch 117/1000
# 14/14 [==============================] - 1s 82ms/step - loss: 1.8784 - val_loss: 1.6163
# Epoch 118/1000
# 14/14 [==============================] - 1s 90ms/step - loss: 1.7967 - val_loss: 1.5976
# Epoch 119/1000
# 14/14 [==============================] - 1s 86ms/step - loss: 2.1565 - val_loss: 1.6437
# Epoch 120/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 2.0147 - val_loss: 1.7362
# Epoch 121/1000
# 14/14 [==============================] - 1s 87ms/step - loss: 1.8581 - val_loss: 1.8823
# Epoch 122/1000
# 14/14 [==============================] - 1s 88ms/step - loss: 1.7125 - val_loss: 1.9000
# Epoch 123/1000
# 14/14 [==============================] - 1s 85ms/step - loss: 2.0665 - val_loss: 1.8742
# Epoch 124/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 2.0559 - val_loss: 1.7959
# Epoch 125/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 1.8695 - val_loss: 1.7801
# Epoch 126/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 1.7167 - val_loss: 1.8010
# Epoch 127/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 1.8633 - val_loss: 1.9705
# Epoch 128/1000
# 14/14 [==============================] - 1s 90ms/step - loss: 1.7706 - val_loss: 2.4152
# Epoch 129/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 1.8787 - val_loss: 2.5687
# Epoch 130/1000
# 14/14 [==============================] - 1s 80ms/step - loss: 1.9050 - val_loss: 2.1739
# Epoch 131/1000
# 14/14 [==============================] - 1s 85ms/step - loss: 1.7531 - val_loss: 2.0154
# Epoch 132/1000
# 14/14 [==============================] - 1s 88ms/step - loss: 1.9460 - val_loss: 1.7726
# Epoch 133/1000
# 14/14 [==============================] - 1s 92ms/step - loss: 1.8774 - val_loss: 1.8165
# Epoch 134/1000
# 14/14 [==============================] - 1s 92ms/step - loss: 2.3650 - val_loss: 1.8154
# Epoch 135/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 1.8715 - val_loss: 1.8294
# Epoch 136/1000
# 14/14 [==============================] - 1s 77ms/step - loss: 1.9034 - val_loss: 2.1875
# Epoch 137/1000
# 14/14 [==============================] - 1s 80ms/step - loss: 2.2574 - val_loss: 2.1777
# Epoch 138/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 2.3576 - val_loss: 2.2920
# Epoch 139/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 1.8601 - val_loss: 2.4342
# Epoch 140/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 1.9819 - val_loss: 2.3460
# Epoch 141/1000
# 14/14 [==============================] - 1s 88ms/step - loss: 2.1643 - val_loss: 2.2533
# Epoch 142/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 1.8704 - val_loss: 1.8208
# Epoch 143/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 1.9134 - val_loss: 1.7737
# Epoch 144/1000
# 14/14 [==============================] - 1s 82ms/step - loss: 1.7859 - val_loss: 1.8187
# Epoch 145/1000
# 14/14 [==============================] - 1s 77ms/step - loss: 1.9358 - val_loss: 1.7197
# Epoch 146/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 1.9425 - val_loss: 1.6763
# Epoch 147/1000
# 14/14 [==============================] - 1s 86ms/step - loss: 1.7443 - val_loss: 1.8902
# Epoch 148/1000
# 14/14 [==============================] - 1s 77ms/step - loss: 2.1162 - val_loss: 1.8177
# Epoch 149/1000
# 14/14 [==============================] - 1s 85ms/step - loss: 1.9783 - val_loss: 2.0109
# Epoch 150/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 1.9256 - val_loss: 1.9300
# Epoch 151/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 2.0429 - val_loss: 1.8065
# Epoch 152/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 2.2080 - val_loss: 1.9226
# Epoch 153/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 2.0566 - val_loss: 1.7095
# Epoch 154/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 1.8927 - val_loss: 1.7587
# Epoch 155/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 2.0721 - val_loss: 1.8639
# Epoch 156/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 2.0433 - val_loss: 2.0945
# Epoch 157/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 1.7781 - val_loss: 2.1560
# Epoch 158/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 2.0777 - val_loss: 2.1782
# Epoch 159/1000
# 14/14 [==============================] - 1s 88ms/step - loss: 1.9258 - val_loss: 2.1865
# Epoch 160/1000
# 14/14 [==============================] - 1s 87ms/step - loss: 1.8713 - val_loss: 2.0888
# Epoch 161/1000
# 14/14 [==============================] - 1s 67ms/step - loss: 1.9204 - val_loss: 2.5169
# Epoch 162/1000
# 14/14 [==============================] - 1s 70ms/step - loss: 1.7603 - val_loss: 2.9862
# Epoch 163/1000
# 14/14 [==============================] - 1s 80ms/step - loss: 2.2144 - val_loss: 3.3819
# Epoch 164/1000
# 14/14 [==============================] - 1s 80ms/step - loss: 1.7686 - val_loss: 2.8693
# Epoch 165/1000
# 14/14 [==============================] - 1s 90ms/step - loss: 1.8812 - val_loss: 2.4980
# Epoch 166/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 1.9368 - val_loss: 2.3023
# Epoch 167/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 2.0028 - val_loss: 2.1610
# Epoch 168/1000
# 14/14 [==============================] - 1s 85ms/step - loss: 1.9312 - val_loss: 2.2076
# Epoch 169/1000
# 14/14 [==============================] - 1s 85ms/step - loss: 2.1685 - val_loss: 2.6345
# Epoch 170/1000
# 14/14 [==============================] - 1s 70ms/step - loss: 1.7957 - val_loss: 2.5614
# Epoch 171/1000
# 14/14 [==============================] - 1s 70ms/step - loss: 1.9349 - val_loss: 3.1080
# Epoch 172/1000
# 14/14 [==============================] - 1s 68ms/step - loss: 2.1599 - val_loss: 3.2045
# Epoch 173/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 1.9754 - val_loss: 2.9087
# Epoch 174/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 2.0092 - val_loss: 2.8068
# Epoch 175/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 1.7134 - val_loss: 2.9872
# Epoch 176/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 1.7138 - val_loss: 2.6450
# Epoch 177/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 2.2004 - val_loss: 2.6084
# Epoch 178/1000
# 14/14 [==============================] - 1s 85ms/step - loss: 1.7085 - val_loss: 2.1591
# Epoch 179/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 1.9853 - val_loss: 1.7488
# Epoch 180/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 1.8925 - val_loss: 1.9664
# Epoch 181/1000
# 14/14 [==============================] - 1s 91ms/step - loss: 2.0453 - val_loss: 1.9414
# Epoch 182/1000
# 14/14 [==============================] - 1s 82ms/step - loss: 1.6829 - val_loss: 2.1350
# Epoch 183/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 1.8309 - val_loss: 2.0778
# Epoch 184/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 1.8203 - val_loss: 2.2902
# Epoch 185/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 1.8756 - val_loss: 2.2067
# Epoch 186/1000
# 14/14 [==============================] - 1s 88ms/step - loss: 2.0249 - val_loss: 2.1078
# Epoch 187/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 1.7723 - val_loss: 2.0372
# Epoch 188/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 1.7009 - val_loss: 1.8519
# Epoch 189/1000
# 14/14 [==============================] - 1s 88ms/step - loss: 1.9918 - val_loss: 1.8998
# Epoch 190/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 2.0869 - val_loss: 1.9902
# Epoch 191/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 1.6524 - val_loss: 1.8413
# Epoch 192/1000
# 14/14 [==============================] - 1s 78ms/step - loss: 1.9526 - val_loss: 2.2311
# Epoch 193/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 1.9150 - val_loss: 2.0539
# Epoch 194/1000
# 14/14 [==============================] - 1s 82ms/step - loss: 1.8462 - val_loss: 1.8587
# Epoch 195/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 2.0725 - val_loss: 1.8677
# Epoch 196/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 1.8022 - val_loss: 1.9157
# Epoch 197/1000
# 14/14 [==============================] - 1s 87ms/step - loss: 2.1922 - val_loss: 1.9658
# Epoch 198/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 1.8583 - val_loss: 2.6088
# Epoch 199/1000
# 14/14 [==============================] - 1s 78ms/step - loss: 1.7233 - val_loss: 2.1849
# Epoch 200/1000
# 14/14 [==============================] - 1s 90ms/step - loss: 1.9423 - val_loss: 2.0347
# Epoch 201/1000
# 14/14 [==============================] - 1s 88ms/step - loss: 1.7978 - val_loss: 2.6869
# Epoch 202/1000
# 14/14 [==============================] - 1s 90ms/step - loss: 1.7464 - val_loss: 2.0723
# Epoch 203/1000
# 14/14 [==============================] - 1s 83ms/step - loss: 1.7322 - val_loss: 1.8792
# Epoch 204/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 2.0439 - val_loss: 1.7140
# Epoch 205/1000
# 14/14 [==============================] - 1s 77ms/step - loss: 1.7590 - val_loss: 1.7519
# Epoch 206/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 1.7544 - val_loss: 1.6836
# Epoch 207/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 1.8220 - val_loss: 1.7956
# Epoch 208/1000
# 14/14 [==============================] - 1s 88ms/step - loss: 1.9831 - val_loss: 1.8574
# Epoch 209/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 2.0109 - val_loss: 2.1306
# Epoch 210/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 1.8654 - val_loss: 2.2118
# Epoch 211/1000
# 14/14 [==============================] - 1s 88ms/step - loss: 1.8145 - val_loss: 2.0465
# Epoch 212/1000
# 14/14 [==============================] - 1s 85ms/step - loss: 1.7447 - val_loss: 2.4289
# Epoch 213/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 1.9687 - val_loss: 1.9455
# Epoch 214/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 1.8408 - val_loss: 2.8887
# Epoch 215/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 2.0529 - val_loss: 3.9612
# Epoch 216/1000
# 14/14 [==============================] - 1s 82ms/step - loss: 1.7363 - val_loss: 5.9441
# Epoch 217/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 1.8754 - val_loss: 5.8559
# Epoch 218/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 1.7574 - val_loss: 4.0888
# Epoch 219/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 1.9181 - val_loss: 4.0706
# Epoch 220/1000
# 14/14 [==============================] - 1s 68ms/step - loss: 2.1862 - val_loss: 4.2400
# Epoch 221/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 1.7689 - val_loss: 6.0882
# Epoch 222/1000
# 14/14 [==============================] - 1s 68ms/step - loss: 1.9230 - val_loss: 4.7598
# Epoch 223/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 1.9072 - val_loss: 4.8819
# Epoch 224/1000
# 14/14 [==============================] - 1s 68ms/step - loss: 1.7815 - val_loss: 3.6991
# Epoch 225/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 1.6472 - val_loss: 2.6523
# Epoch 226/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 1.9733 - val_loss: 2.4400
# Epoch 227/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 1.9950 - val_loss: 1.9433
# Epoch 228/1000
# 14/14 [==============================] - 1s 80ms/step - loss: 2.3467 - val_loss: 2.5996
# Epoch 229/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 2.1353 - val_loss: 2.4244
# Epoch 230/1000
# 14/14 [==============================] - 1s 89ms/step - loss: 1.7555 - val_loss: 2.2766
# Epoch 231/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 2.4407 - val_loss: 2.4219
# Epoch 232/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 1.7198 - val_loss: 2.4660
# Epoch 233/1000
# 14/14 [==============================] - 1s 83ms/step - loss: 1.7690 - val_loss: 2.3995
# Epoch 234/1000
# 14/14 [==============================] - 1s 78ms/step - loss: 1.5659 - val_loss: 2.4939
# Epoch 235/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 2.0499 - val_loss: 2.2397
# Epoch 236/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 1.9074 - val_loss: 2.3722
# Epoch 237/1000
# 14/14 [==============================] - 1s 68ms/step - loss: 1.6749 - val_loss: 2.5243
# Epoch 238/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 1.6346 - val_loss: 2.7913
# Epoch 239/1000
# 14/14 [==============================] - 1s 66ms/step - loss: 1.6390 - val_loss: 2.6290
# Epoch 240/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 1.7587 - val_loss: 2.2283
# Epoch 241/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 1.9740 - val_loss: 2.2201
# Epoch 242/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 2.1745 - val_loss: 2.4850
# Epoch 243/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 1.7793 - val_loss: 2.6320
# Epoch 244/1000
# 14/14 [==============================] - 1s 70ms/step - loss: 1.8710 - val_loss: 2.5817
# Epoch 245/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 2.0422 - val_loss: 2.1445
# Epoch 246/1000
# 14/14 [==============================] - 1s 70ms/step - loss: 1.9065 - val_loss: 2.5632
# Epoch 247/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 1.8549 - val_loss: 2.2706
# Epoch 248/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 1.6639 - val_loss: 2.4094
# Epoch 249/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 1.9792 - val_loss: 2.0147
# Epoch 250/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 1.8938 - val_loss: 2.0367
# Epoch 251/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 1.9560 - val_loss: 3.0010
# Epoch 252/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 1.7679 - val_loss: 2.6793
# Epoch 253/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 1.9002 - val_loss: 4.1857
# Epoch 254/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 1.5961 - val_loss: 4.2261
# Epoch 255/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 2.1797 - val_loss: 4.8029
# Epoch 256/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 1.7867 - val_loss: 4.4733
# Epoch 257/1000
# 14/14 [==============================] - 1s 70ms/step - loss: 1.6204 - val_loss: 3.7374
# Epoch 258/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 1.8270 - val_loss: 3.0360
# Epoch 259/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 1.5299 - val_loss: 2.3764
# Epoch 260/1000
# 14/14 [==============================] - 1s 66ms/step - loss: 1.9218 - val_loss: 3.1122
# Epoch 261/1000
# 14/14 [==============================] - 1s 66ms/step - loss: 2.1571 - val_loss: 2.2831
# Epoch 262/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 1.6988 - val_loss: 2.1727
# Epoch 263/1000
# 14/14 [==============================] - 1s 68ms/step - loss: 1.6576 - val_loss: 2.4101
# Epoch 264/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 1.7741 - val_loss: 2.5838
# Epoch 265/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 1.8442 - val_loss: 2.3146
# Epoch 266/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 1.5854 - val_loss: 2.5971
# Epoch 267/1000
# 14/14 [==============================] - 1s 67ms/step - loss: 1.6557 - val_loss: 2.7039
# Epoch 268/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 2.1203 - val_loss: 2.9778
# Epoch 269/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 1.8543 - val_loss: 2.3503
# Epoch 270/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 1.7822 - val_loss: 2.0492
# Epoch 271/1000
# 14/14 [==============================] - 1s 67ms/step - loss: 1.6399 - val_loss: 2.1157
# Epoch 272/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 1.8969 - val_loss: 1.7325
# Epoch 273/1000
# 14/14 [==============================] - 1s 70ms/step - loss: 1.7170 - val_loss: 1.8155
# Epoch 274/1000
# 14/14 [==============================] - 1s 67ms/step - loss: 1.7034 - val_loss: 2.0320
# Epoch 275/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 1.5776 - val_loss: 2.2638
# Epoch 276/1000
# 14/14 [==============================] - 1s 66ms/step - loss: 1.5641 - val_loss: 2.4732
# Epoch 277/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 1.7055 - val_loss: 3.0787
# Epoch 278/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 1.5964 - val_loss: 2.9269
# Epoch 279/1000
# 14/14 [==============================] - 1s 67ms/step - loss: 2.0074 - val_loss: 2.9884
# Epoch 280/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 1.6947 - val_loss: 2.6056
# Epoch 281/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 1.7485 - val_loss: 2.2189
# Epoch 282/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 1.5216 - val_loss: 2.8978
# Epoch 283/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 1.7448 - val_loss: 2.5808
# Epoch 284/1000
# 14/14 [==============================] - 1s 86ms/step - loss: 1.7061 - val_loss: 2.2503
# Epoch 285/1000
# 14/14 [==============================] - 1s 78ms/step - loss: 1.8216 - val_loss: 2.5699
# Epoch 286/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 1.6844 - val_loss: 2.4803
# Epoch 287/1000
# 14/14 [==============================] - 1s 88ms/step - loss: 1.7777 - val_loss: 2.7818
# Epoch 288/1000
# 14/14 [==============================] - 1s 69ms/step - loss: 1.5645 - val_loss: 2.9984
# Epoch 289/1000
# 14/14 [==============================] - 1s 82ms/step - loss: 2.1416 - val_loss: 2.8754
# Epoch 290/1000
# 14/14 [==============================] - 1s 89ms/step - loss: 1.6459 - val_loss: 2.6832
# Epoch 291/1000
# 14/14 [==============================] - 1s 80ms/step - loss: 1.6956 - val_loss: 3.1234
# Epoch 292/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 1.8335 - val_loss: 3.2482
# Epoch 293/1000
# 14/14 [==============================] - 1s 89ms/step - loss: 1.6786 - val_loss: 2.7202
# Epoch 294/1000
# 14/14 [==============================] - 1s 89ms/step - loss: 1.8008 - val_loss: 2.1143
# Epoch 295/1000
# 14/14 [==============================] - 1s 72ms/step - loss: 1.8665 - val_loss: 2.3167
# Epoch 296/1000
# 14/14 [==============================] - 1s 70ms/step - loss: 1.7991 - val_loss: 2.3549
# Epoch 297/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 1.9150 - val_loss: 2.9114
# Epoch 298/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 2.0398 - val_loss: 2.5845
# Epoch 299/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 1.7144 - val_loss: 2.8272
# Epoch 300/1000
# 14/14 [==============================] - 1s 77ms/step - loss: 2.0142 - val_loss: 3.4696
# Epoch 301/1000
# 14/14 [==============================] - 1s 78ms/step - loss: 1.5772 - val_loss: 3.0718
# Epoch 302/1000
# 14/14 [==============================] - 1s 88ms/step - loss: 1.7049 - val_loss: 2.8001
# Epoch 303/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 1.9842 - val_loss: 2.5619
# Epoch 304/1000
# 14/14 [==============================] - 1s 67ms/step - loss: 1.7249 - val_loss: 2.3047
# Epoch 305/1000
# 14/14 [==============================] - 1s 73ms/step - loss: 1.9974 - val_loss: 2.0530
# Epoch 306/1000
# 14/14 [==============================] - 1s 77ms/step - loss: 1.5459 - val_loss: 1.8506
# Epoch 307/1000
# 14/14 [==============================] - 1s 91ms/step - loss: 1.6787 - val_loss: 1.7199
# Epoch 308/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 1.6266 - val_loss: 1.6495
# Epoch 309/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 1.7347 - val_loss: 1.5912
# Epoch 310/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 1.6486 - val_loss: 1.5240
# Epoch 311/1000
# 14/14 [==============================] - 1s 68ms/step - loss: 1.7087 - val_loss: 1.4639
# Epoch 312/1000
# 14/14 [==============================] - 1s 71ms/step - loss: 1.7443 - val_loss: 1.4623
# Epoch 313/1000
# 14/14 [==============================] - 1s 83ms/step - loss: 1.6229 - val_loss: 1.4576
# Epoch 314/1000
# 14/14 [==============================] - 1s 78ms/step - loss: 1.6464 - val_loss: 1.4410
# Epoch 315/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 2.1226 - val_loss: 1.4332
# Epoch 316/1000
# 14/14 [==============================] - 1s 85ms/step - loss: 1.8033 - val_loss: 1.4305
# Epoch 317/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 1.6676 - val_loss: 1.4339
# Epoch 318/1000
# 14/14 [==============================] - ETA: 0s - loss: 1.749 - 1s 88ms/step - loss: 1.7492 - val_loss: 1.4145
# Epoch 319/1000
# 14/14 [==============================] - 1s 80ms/step - loss: 1.5861 - val_loss: 1.3885
# Epoch 320/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 1.5831 - val_loss: 1.3957
# Epoch 321/1000
# 14/14 [==============================] - 1s 80ms/step - loss: 1.6274 - val_loss: 1.4031
# Epoch 322/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 1.6668 - val_loss: 1.4045
# Epoch 323/1000
# 14/14 [==============================] - 1s 83ms/step - loss: 1.6225 - val_loss: 1.4040
# Epoch 324/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 2.0588 - val_loss: 1.4055
# Epoch 325/1000
# 14/14 [==============================] - 1s 82ms/step - loss: 1.7166 - val_loss: 1.4029
# Epoch 326/1000
# 14/14 [==============================] - 1s 85ms/step - loss: 1.5341 - val_loss: 1.4114
# Epoch 327/1000
# 14/14 [==============================] - 1s 80ms/step - loss: 1.6441 - val_loss: 1.4181
# Epoch 328/1000
# 14/14 [==============================] - 1s 89ms/step - loss: 1.5757 - val_loss: 1.4559
# Epoch 329/1000
# 14/14 [==============================] - 1s 78ms/step - loss: 1.6446 - val_loss: 1.4186
# Epoch 330/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 1.5197 - val_loss: 1.4069
# Epoch 331/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 1.7378 - val_loss: 1.4032
# Epoch 332/1000
# 14/14 [==============================] - 1s 86ms/step - loss: 1.9133 - val_loss: 1.3921
# Epoch 333/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 1.6832 - val_loss: 1.4068
# Epoch 334/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 1.6943 - val_loss: 1.4090
# Epoch 335/1000
# 14/14 [==============================] - 1s 78ms/step - loss: 1.6576 - val_loss: 1.4073
# Epoch 336/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 1.6153 - val_loss: 1.4162
# Epoch 337/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 1.6213 - val_loss: 1.4188
# Epoch 338/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 1.5609 - val_loss: 1.4127
# Epoch 339/1000
# 14/14 [==============================] - 1s 78ms/step - loss: 1.6489 - val_loss: 1.4146
# Epoch 340/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 1.6316 - val_loss: 1.4274
# Epoch 341/1000
# 14/14 [==============================] - 1s 84ms/step - loss: 2.1270 - val_loss: 1.4197
# Epoch 342/1000
# 14/14 [==============================] - 1s 82ms/step - loss: 1.6050 - val_loss: 1.4301
# Epoch 343/1000
# 14/14 [==============================] - 1s 82ms/step - loss: 1.7208 - val_loss: 1.4369
# Epoch 344/1000
# 14/14 [==============================] - 1s 80ms/step - loss: 1.6649 - val_loss: 1.4241
# Epoch 345/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 1.7951 - val_loss: 1.4204
# Epoch 346/1000
# 14/14 [==============================] - 1s 83ms/step - loss: 1.8031 - val_loss: 1.4196
# Epoch 347/1000
# 14/14 [==============================] - 1s 85ms/step - loss: 1.5581 - val_loss: 1.4162
# Epoch 348/1000
# 14/14 [==============================] - 1s 83ms/step - loss: 1.5280 - val_loss: 1.4158
# Epoch 349/1000
# 14/14 [==============================] - 1s 80ms/step - loss: 1.6859 - val_loss: 1.4089
# Epoch 350/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 1.6300 - val_loss: 1.4155
# Epoch 351/1000
# 14/14 [==============================] - 1s 82ms/step - loss: 1.5685 - val_loss: 1.4376
# Epoch 352/1000
# 14/14 [==============================] - 1s 86ms/step - loss: 1.7029 - val_loss: 1.4544
# Epoch 353/1000
# 14/14 [==============================] - 1s 87ms/step - loss: 1.6578 - val_loss: 1.4476
# Epoch 354/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 1.8362 - val_loss: 1.4314
# Epoch 355/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 1.7514 - val_loss: 1.4077
# Epoch 356/1000
# 14/14 [==============================] - 1s 85ms/step - loss: 1.7494 - val_loss: 1.4052
# Epoch 357/1000
# 14/14 [==============================] - 1s 88ms/step - loss: 1.6867 - val_loss: 1.4008
# Epoch 358/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 1.5653 - val_loss: 1.3972
# Epoch 359/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 1.6764 - val_loss: 1.3988
# Epoch 360/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 1.7436 - val_loss: 1.4032
# Epoch 361/1000
# 14/14 [==============================] - 1s 74ms/step - loss: 1.7247 - val_loss: 1.4093
# Epoch 362/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 1.5447 - val_loss: 1.4041
# Epoch 363/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 1.6443 - val_loss: 1.4026
# Epoch 364/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 1.6889 - val_loss: 1.4049
# Epoch 365/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 1.6958 - val_loss: 1.4136
# Epoch 366/1000
# 14/14 [==============================] - 1s 80ms/step - loss: 1.8165 - val_loss: 1.4052
# Epoch 367/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 1.7011 - val_loss: 1.4095
# Epoch 368/1000
# 14/14 [==============================] - 1s 79ms/step - loss: 1.6730 - val_loss: 1.4133
# Epoch 369/1000
# 14/14 [==============================] - 1s 80ms/step - loss: 1.7652 - val_loss: 1.4200
# Epoch 370/1000
# 14/14 [==============================] - 1s 83ms/step - loss: 1.7641 - val_loss: 1.4072
# Epoch 371/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 1.7039 - val_loss: 1.4015
# Epoch 372/1000
# 14/14 [==============================] - 1s 94ms/step - loss: 1.5714 - val_loss: 1.3947
# Epoch 373/1000
# 14/14 [==============================] - 1s 81ms/step - loss: 1.4437 - val_loss: 1.3982
# Epoch 374/1000
# 14/14 [==============================] - 1s 75ms/step - loss: 1.4200 - val_loss: 1.3998
# Epoch 375/1000
# 14/14 [==============================] - 1s 76ms/step - loss: 2.2289 - val_loss: 1.4013
# C:\Users\cai-sh\anaconda3\envs\wc_ratio\lib\site-packages\keras\utils\generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
# Plot the Loss graph

if train_mode == True:
    plt.subplots(figsize=(6,4.5))
    plt.plot(history.history['loss'],'b-',label='train_loss')
    plt.plot(history.history['val_loss'],'b-',label='val_loss',color='r')

    plt.legend(prop={'size': 20})

    plt.xlabel("Epoch", fontdict={'size': 20})
    plt.ylabel("Loss", fontdict={'size': 20})

    plt.xticks((0, 200, 400, 600, 800, 1000),fontsize=15)
    plt.yticks(fontsize=15)

    plt.grid(True)
    plt.show()

# %%
### Print the prediction results

test_losses = []
p_result_0 = []

# Load Model & Make Results
model.load_weights(last_model_save_dir)
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam())

test_losses = model.evaluate(x_test, y_test, verbose=0)
p_result_0 = model.predict(x_test)

p_result_0
# Out:
# array([[60.232185],
#        [55.21211 ],
#        [50.07072 ],
#        ...,
#        [40.181705],
#        [49.581116],
#        [55.241116]], dtype=float32)

# %%
### print RMSE and R2-score

rmse_0 = round(mean_squared_error(y_test, p_result_0, squared=False), 4)
r2_0 = round(r2_score(y_test, p_result_0), 4)

print(f"RMSE : {rmse_0}")
print(f"r2_score : {r2_0}")
# Out:
# RMSE : 1.177
# r2_score : 0.9669

# %%
# Preprocess the results (group by the same y-value).
p_list_0 = [[]for i in range(len(WC_name_tag))]

for i,test_water in enumerate(y_test):    
    for j,wc_name in enumerate(WC_name_tag):
        
        if i==len(y_test):
            break
            
#   array([60.008026], dtype=float32),
#   array([59.952843], dtype=float32),
#   array([59.878304], dtype=float32),
#   array([60.398273], dtype=float32),
#   array([60.262344], dtype=float32),
#   array([58.62038], dtype=float32),
#   array([59.895092], dtype=float32),
#   array([59.881012], dtype=float32),
#   array([59.907547], dtype=float32),
#   array([60.121315], dtype=float32),
#   array([59.89763], dtype=float32),
#   array([60.09383], dtype=float32),
#   array([60.002514], dtype=float32),
#   array([60.093822], dtype=float32),
#   array([59.087193], dtype=float32),
#   array([60.177036], dtype=float32),
#   array([59.881012], dtype=float32),
#   array([60.014355], dtype=float32),
#   array([59.97584], dtype=float32),
#   array([60.061], dtype=float32),
#   array([59.91183], dtype=float32),
#   array([60.075253], dtype=float32),
#   array([60.085472], dtype=float32),
#   array([60.075253], dtype=float32),
#   array([60.02484], dtype=float32),
#   array([59.931408], dtype=float32),
#   array([60.330647], dtype=float32),
#   array([59.91148], dtype=float32),
#   array([59.949005], dtype=float32),
#   array([59.75224], dtype=float32),
#   array([60.10025], dtype=float32),
#   array([59.889828], dtype=float32),
#   array([59.96993], dtype=float32),
#   array([59.881012], dtype=float32),
#   array([60.03498], dtype=float32),
#   array([60.109406], dtype=float32),
#   array([59.655376], dtype=float32),
#   array([60.001152], dtype=float32),
#   array([60.16866], dtype=float32),
#   array([59.969826], dtype=float32),
#   array([59.891277], dtype=float32),
#   array([60.075253], dtype=float32),
#   array([60.09632], dtype=float32),
#   array([59.769936], dtype=float32),
#   array([59.974308], dtype=float32),
#   array([59.73494], dtype=float32),
#   array([60.212883], dtype=float32),
#   array([59.70158], dtype=float32),
#   array([59.900677], dtype=float32),
#   array([60.193375], dtype=float32),
#   array([59.945602], dtype=float32),
#   array([59.767254], dtype=float32),
#   array([60.030792], dtype=float32),
#   array([60.01657], dtype=float32),
#   array([59.8473], dtype=float32),
#   array([59.994972], dtype=float32),
#   array([59.77396], dtype=float32),
#   array([59.844555], dtype=float32),
#   array([60.03973], dtype=float32),
#   array([59.42415], dtype=float32),
#   array([59.848747], dtype=float32),
#   array([60.141758], dtype=float32),
#   array([59.76653], dtype=float32),
#   array([59.934235], dtype=float32),
#   array([60.082115], dtype=float32),
#   array([60.221657], dtype=float32),
#   array([60.082115], dtype=float32),
#   array([60.001324], dtype=float32),
#   array([59.84242], dtype=float32),
#   array([60.045033], dtype=float32),
#   array([59.70158], dtype=float32),
#   array([60.04346], dtype=float32),
#   array([59.92791], dtype=float32),
#   array([59.74584], dtype=float32),
#   array([60.087727], dtype=float32),
#   array([60.169994], dtype=float32),
#   array([60.225887], dtype=float32),
#   array([60.39975], dtype=float32),
#   array([60.134148], dtype=float32),
#   array([60.053436], dtype=float32),
#   array([60.244137], dtype=float32),
#   array([59.831932], dtype=float32),
#   array([59.756092], dtype=float32),
#   array([60.001324], dtype=float32),
#   array([60.09794], dtype=float32),
#   array([59.66858], dtype=float32),
#   array([59.952824], dtype=float32),
#   array([60.388054], dtype=float32),
#   array([59.84781], dtype=float32),
#   array([60.080833], dtype=float32),
#   array([59.778828], dtype=float32),
#   array([60.075253], dtype=float32),
#   array([59.78098], dtype=float32),
#   array([60.027397], dtype=float32),
#   array([60.113117], dtype=float32),
#   array([59.767544], dtype=float32),
#   array([59.996696], dtype=float32),
#   array([60.03737], dtype=float32),
#   array([60.30513], dtype=float32),
#   array([60.16289], dtype=float32),
#   array([59.970657], dtype=float32),
#   array([60.218327], dtype=float32),
#   array([59.918156], dtype=float32),
#   array([59.67842], dtype=float32),
#   array([59.792908], dtype=float32),
#   array([59.649567], dtype=float32),
#   array([60.124928], dtype=float32),
#   array([60.001152], dtype=float32),
#   array([60.19682], dtype=float32),
#   array([60.234272], dtype=float32),
#   array([59.93429], dtype=float32),
#   array([60.06602], dtype=float32),
#   array([60.08989], dtype=float32),
#   array([59.879875], dtype=float32),
#   array([60.075253], dtype=float32),
#   array([59.680866], dtype=float32),
#   array([60.16583], dtype=float32),
#   array([59.734554], dtype=float32),
#   array([59.057995], dtype=float32),
#   array([60.177353], dtype=float32),
#   array([59.789265], dtype=float32),
#   array([59.875645], dtype=float32),
#   array([60.04115], dtype=float32),
#   array([59.731167], dtype=float32),
#   array([59.924618], dtype=float32),
#   array([60.351177], dtype=float32),
#   array([59.90916], dtype=float32),
#   array([59.72575], dtype=float32),
#   array([60.079327], dtype=float32),
#   array([59.90425], dtype=float32),
#   array([60.219017], dtype=float32),
#   array([60.053436], dtype=float32),
#   array([59.90343], dtype=float32),
#   array([59.810318], dtype=float32),
#   array([60.124454], dtype=float32),
#   array([60.018757], dtype=float32),
#   array([60.106884], dtype=float32),
#   array([60.10173], dtype=float32),
#   array([60.02175], dtype=float32),
#   array([59.839558], dtype=float32),
#   array([60.152256], dtype=float32),
#   array([59.934544], dtype=float32),
#   array([60.215042], dtype=float32),
#   array([60.100582], dtype=float32),
#   array([59.93314], dtype=float32),
#   array([59.600346], dtype=float32),
#   array([59.738914], dtype=float32),
#   array([59.981407], dtype=float32),
#   array([60.2097], dtype=float32),
#   array([59.38181], dtype=float32),
#   array([60.208103], dtype=float32),
#   array([60.058044], dtype=float32),
#   array([59.64736], dtype=float32),
#   array([59.90813], dtype=float32),
#   array([60.203255], dtype=float32),
#   array([59.548695], dtype=float32),
#   array([60.249718], dtype=float32),
#   array([60.247272], dtype=float32),
#   array([60.056293], dtype=float32),
#   array([59.813282], dtype=float32),
#   array([60.055916], dtype=float32),
#   array([60.020893], dtype=float32),
#   array([60.307274], dtype=float32),
#   array([47.85588], dtype=float32),
#   array([60.24451], dtype=float32),
#   array([60.231377], dtype=float32),
#   array([60.075253], dtype=float32),
#   array([59.881012], dtype=float32),
#   array([60.002514], dtype=float32),
#   array([60.34408], dtype=float32),
#   array([59.827087], dtype=float32),
#   array([59.907963], dtype=float32),
#   array([59.9982], dtype=float32),
#   array([60.2526], dtype=float32),
#   array([59.888016], dtype=float32),
#   array([60.036354], dtype=float32),
#   array([59.851814], dtype=float32),
#   array([59.285385], dtype=float32),
#   array([60.131878], dtype=float32),
#   array([60.058537], dtype=float32),
#   array([59.980545], dtype=float32),
#   array([60.03682], dtype=float32),
#   array([59.881012], dtype=float32),
#   array([60.1216], dtype=float32),
#   array([59.917305], dtype=float32),
#   array([60.056133], dtype=float32),
#   array([60.12622], dtype=float32),
#   array([60.234272], dtype=float32),
#   array([60.09379], dtype=float32),
#   array([60.289227], dtype=float32),
#   array([59.874092], dtype=float32),
#   array([59.897198], dtype=float32),
#   array([60.214813], dtype=float32),
#   array([59.767254], dtype=float32),
#   array([59.650322], dtype=float32),
#   array([59.83045], dtype=float32),
#   array([59.73494], dtype=float32),
#   array([60.14147], dtype=float32),
#   array([59.655376], dtype=float32),
#   array([60.162674], dtype=float32),
#   array([60.13292], dtype=float32),
#   array([59.941883], dtype=float32),
#   array([60.230396], dtype=float32),
#   array([59.97584], dtype=float32),
#   array([59.599495], dtype=float32),
#   array([60.14924], dtype=float32),
#   array([59.968483], dtype=float32),
#   array([60.008034], dtype=float32),
#   array([59.852688], dtype=float32),
#   array([60.082115], dtype=float32),
#   array([60.007862], dtype=float32),
#   array([60.262783], dtype=float32),
#   array([60.270073], dtype=float32),
#   array([59.992207], dtype=float32),
#   array([59.955433], dtype=float32),
#   array([59.97478], dtype=float32),
#   array([60.02698], dtype=float32),
#   array([59.910973], dtype=float32),
#   array([59.94739], dtype=float32),
#   array([60.029728], dtype=float32),
#   array([59.761192], dtype=float32),
#   array([59.14113], dtype=float32),
#   array([59.44274], dtype=float32),
#   array([60.212708], dtype=float32),
#   array([59.856377], dtype=float32),
#   array([60.234272], dtype=float32),
#   array([59.801422], dtype=float32),
#   array([60.247272], dtype=float32),
#   array([60.290134], dtype=float32),
#   array([60.00318], dtype=float32),
#   array([60.023396], dtype=float32),
#   array([60.107548], dtype=float32),
#   array([59.94878], dtype=float32),
#   array([60.110138], dtype=float32),
#   array([59.981407], dtype=float32),
#   array([59.94444], dtype=float32),
#   array([59.846336], dtype=float32),
#   array([60.16164], dtype=float32),
#   array([60.13676], dtype=float32),
#   array([60.075253], dtype=float32),
#   array([59.222233], dtype=float32),
#   array([59.767365], dtype=float32),
#   array([60.51172], dtype=float32),
#   array([59.929], dtype=float32),
#   array([60.22363], dtype=float32),
#   array([59.720806], dtype=float32),
#   array([60.066868], dtype=float32),
#   array([59.945034], dtype=float32),
#   array([60.158195], dtype=float32),
#   array([60.133434], dtype=float32),
#   array([59.88055], dtype=float32),
#   array([59.851517], dtype=float32),
#   array([59.832775], dtype=float32),
#   array([60.06453], dtype=float32),
#   array([60.29377], dtype=float32),
#   array([59.93472], dtype=float32),
#   array([59.69256], dtype=float32),
#   array([59.811146], dtype=float32),
#   array([60.001324], dtype=float32),
#   array([60.328175], dtype=float32),
#   array([60.087795], dtype=float32),
#   array([59.964275], dtype=float32),
#   array([59.73494], dtype=float32),
#   array([59.89587], dtype=float32),
#   array([59.977795], dtype=float32),
#   array([60.03851], dtype=float32),
#   array([59.61213], dtype=float32),
#   array([60.001377], dtype=float32),
#   array([60.141953], dtype=float32),
#   array([59.592857], dtype=float32),
#   array([59.981407], dtype=float32),
#   array([59.94523], dtype=float32),
#   array([60.044456], dtype=float32),
#   array([59.98839], dtype=float32),
#   array([60.14924], dtype=float32),
#   array([58.892437], dtype=float32),
#   array([60.06514], dtype=float32),
#   array([59.756355], dtype=float32),
#   array([60.075253], dtype=float32),
#   array([59.73494], dtype=float32),
#   array([59.77238], dtype=float32),
#   array([60.094337], dtype=float32),
#   array([59.999557], dtype=float32),
#   array([60.044456], dtype=float32),
#   array([60.185886], dtype=float32),
#   array([59.918156], dtype=float32),
#   array([60.16563], dtype=float32),
#   array([59.660957], dtype=float32),
#   array([60.16289], dtype=float32),
#   array([59.771957], dtype=float32),
#   array([60.085068], dtype=float32),
#   array([60.02482], dtype=float32),
#   array([59.91638], dtype=float32),
#   array([59.852688], dtype=float32),
#   array([60.024097], dtype=float32),
#   array([59.718082], dtype=float32),
#   array([59.944878], dtype=float32),
#   array([59.91323], dtype=float32),
#   array([59.712955], dtype=float32),
#   array([60.024097], dtype=float32),
#   array([60.075253], dtype=float32),
#   array([60.393658], dtype=float32),
#   array([60.213146], dtype=float32),
#   array([60.03498], dtype=float32),
#   array([59.973316], dtype=float32),
#   array([59.672756], dtype=float32),
#   array([60.22866], dtype=float32),
#   array([60.00608], dtype=float32),
#   array([60.154675], dtype=float32),
#   array([59.87786], dtype=float32),
#   array([60.13169], dtype=float32),
#   array([60.03737], dtype=float32),
#   array([59.842384], dtype=float32),
#   array([59.881012], dtype=float32),
#   array([59.861412], dtype=float32),
#   array([59.981407], dtype=float32),
#   array([60.102055], dtype=float32),
#   array([59.895676], dtype=float32),
#   array([60.001152], dtype=float32),
#   array([59.653255], dtype=float32),
#   array([60.128838], dtype=float32),
#   array([59.780556], dtype=float32),
#   array([59.65209], dtype=float32),
#   array([59.933594], dtype=float32),
#   array([59.77573], dtype=float32),
#   array([59.74584], dtype=float32),
#   array([59.89601], dtype=float32),
#   array([60.03737], dtype=float32),
#   array([60.075253], dtype=float32),
#   array([60.21963], dtype=float32),
#   array([59.873524], dtype=float32),
#   array([60.075253], dtype=float32),
#   array([59.731167], dtype=float32),
#   array([60.011375], dtype=float32),
#   array([59.685066], dtype=float32),
#   array([60.091106], dtype=float32),
#   array([59.959763], dtype=float32),
#   array([59.863663], dtype=float32),
#   array([60.100582], dtype=float32),
#   array([60.249077], dtype=float32),
#   array([59.886654], dtype=float32),
#   array([59.653255], dtype=float32),
#   array([60.07844], dtype=float32),
#   array([60.245773], dtype=float32),
#   array([59.949005], dtype=float32),
#   array([60.024807], dtype=float32),
#   array([60.229023], dtype=float32),
#   array([59.661316], dtype=float32),
#   array([59.961357], dtype=float32),
#   array([59.884903], dtype=float32),
#   array([60.051033], dtype=float32),
#   array([60.23638], dtype=float32),
#   array([59.70158], dtype=float32),
#   array([59.902893], dtype=float32),
#   array([60.03737], dtype=float32),
#   array([59.997974], dtype=float32),
#   array([60.3282], dtype=float32),
#   array([59.767254], dtype=float32),
#   array([59.73494], dtype=float32),
#   array([59.952206], dtype=float32),
#   array([59.93472], dtype=float32),
#   array([60.180283], dtype=float32),
#   array([59.89844], dtype=float32),
#   array([60.15845], dtype=float32),
#   array([60.29682], dtype=float32),
#   array([59.743587], dtype=float32),
#   array([59.75879], dtype=float32),
#   array([60.124107], dtype=float32),
#   array([59.756508], dtype=float32),
#   array([60.15467], dtype=float32),
#   array([59.985336], dtype=float32),
#   array([59.86246], dtype=float32),
#   array([59.839367], dtype=float32),
#   array([60.351177], dtype=float32),
#   array([59.843815], dtype=float32),
#   array([59.655376], dtype=float32),
#   array([60.05638], dtype=float32),
#   array([59.966396], dtype=float32),
#   array([59.979923], dtype=float32),
#   array([59.95274], dtype=float32),
#   array([60.216705], dtype=float32),
#   array([60.22363], dtype=float32),
#   array([60.023396], dtype=float32),
#   array([59.81193], dtype=float32),
#   array([60.12973], dtype=float32),
#   array([60.00553], dtype=float32),
#   array([60.030537], dtype=float32),
#   array([60.256176], dtype=float32),
#   array([59.886654], dtype=float32),
#   array([59.884697], dtype=float32),
#   array([59.881012], dtype=float32),
#   array([60.116108], dtype=float32),
#   array([59.95001], dtype=float32),
#   array([59.227623], dtype=float32),
#   array([60.025593], dtype=float32),
#   array([59.726337], dtype=float32),
#   array([59.862], dtype=float32),
#   array([60.093914], dtype=float32),
#   array([59.884052], dtype=float32),
#   array([60.208103], dtype=float32),
#   array([59.990322], dtype=float32),
#   array([59.70158], dtype=float32),
#   array([59.871105], dtype=float32),
#   array([60.127544], dtype=float32),
#   array([59.91183], dtype=float32),
#   array([60.13169], dtype=float32),
#   array([59.83495], dtype=float32),
#   array([59.951324], dtype=float32),
#   array([59.996746], dtype=float32)]]

# %%
### Print the mean and standard deviation of the predicted WCR (Water-Cement Ratio).

p_list_mean = [[]for i in range(len(WC_name_tag))]
p_list_std = [[]for i in range(len(WC_name_tag))]

for i in range(len(WC_name_tag)):
    tmp_mean = np.mean(p_list_0[i])
    tmp_std = np.std(p_list_0[i])
    
    p_list_mean[i].append(tmp_mean)
    p_list_std[i].append(tmp_std)

flattened_mean = [item for sublist in p_list_mean for item in sublist]
flattened_std = [item for sublist in p_list_std for item in sublist]

print(f"mean per WCR: {flattened_mean}\n")
print(f"std per WCR: {flattened_std}")
# Out:
# mean per WCR: [40.26165, 43.224342, 45.29496, 46.714672, 49.88307, 52.262444, 54.6818, 57.366783, 59.945858]
#
# std per WCR: [0.847124, 1.2694213, 1.1616027, 1.2037301, 1.4014723, 1.4614879, 0.98106086, 0.6739395, 0.59056216]

# %%
### Plot graph

x_axis = [40, 42.5, 45, 47.5, 50, 52.5, 55, 57.5, 60]
y_axis = [37.5, 40, 42.5, 45, 47.5, 50, 52.5, 55, 57.5, 60, 62.5]
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:olive', 'tab:cyan']

fig, ax = plt.subplots(figsize=(6, 6))

for i, tmp_color in enumerate(colors):
    ax.errorbar(WC_name_tag[i], flattened_mean[i], yerr=flattened_std[i], linestyle='None', markeredgecolor='k', ecolor='k', marker='o', markersize=7.5, color=tmp_color, capsize=5, elinewidth=1.5)

# equal line
plt.plot([40, 42.5, 45, 47.5, 50, 52.5, 55, 57.5, 60], [40, 42.5, 45, 47.5, 50, 52.5, 55, 57.5, 60], c='k', ls='--', lw=1, label='Equality line')

# upper line
plt.plot([40, 42.5, 45, 47.5, 50, 52.5, 55, 57.5, 60], [42, 44.5, 47, 49.5, 52, 54.5, 57, 59.5, 62], c='k', ls='--', lw=0.5, label='±2% line')

# under lone
plt.plot([40, 42.5, 45, 47.5, 50, 52.5, 55, 57.5, 60], [38, 40.5, 43, 45.5, 48, 50.5, 53, 55.5, 58], c='k', ls='--', lw=0.5)

plt.xlabel('Actual w/c ratio (%)', fontdict={'size': 20})
plt.ylabel('Estimated w/c ratio (%)', fontdict={'size': 20})
plt.xticks(x_axis, fontsize=15)
plt.yticks(y_axis, fontsize=15)
plt.legend(fontsize=14)

plt.show()
