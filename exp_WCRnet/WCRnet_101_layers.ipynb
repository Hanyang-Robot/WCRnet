# %%
import os,sys
import random
import pandas as pd
import numpy as np
import seaborn as sns

import tensorflow as tf
import matplotlib as plt
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error, r2_score

# %%
### Enter the data folder name and WCR information

# Load the data folder path
path = os.getcwd()
path_upper = path + '/data_mortar'

# WCR information
WC_name_tag = [40, 42.5, 45, 47.5, 50, 52.5, 55, 57.5, 60]

# Fit the random seed
seed_data = 4885
random.seed(seed_data)
np.random.seed(seed_data)
os.environ["PYTHONHASHSEED"] = str(seed_data)
tf.random.set_seed(seed_data)

# Set the name of the training model file to save.
last_model_save_name = "WCRnet_101_layers.h5"
last_model_save_dir = path + f'/save_models/{last_model_save_name}'

# Layer paramter for WCRnet
layer_list = [3, 4, 23, 3]

# Parameter for Training
epochs = 1000                 # training epochs
batch_sizes = 1024            # batch size
initial_learning_rate = 0.1   # initial learning rate
input_shape = 6               # input shape of the model

# Parameter for K-FOLD validation
k_fold_num = 4                # number of K-Folds
current_fold = 0              # Set the 'K' : 0 | 1 | 2 | 3

# %%
### Data normalization

# Normalize to the minimum and maximum sensor measurement values.
def sense_min_max_Normalization(input_data, min_value, max_value):
    data = (input_data - min_value) / (max_value - min_value) 
    
    return data

def data_set_normalization(data):
    # sensor_min_value
    vwc_min = 0
    ec_min = 0
    salinity_min = 0
    tds_min = 0
    epsilon_min = 0
    temp_min = -40
    
    # sensor_max_value
    vwc_max = 100
    ec_max = 20000
    salinity_max = 20000
    tds_max = 20000
    temp_max = 80
    epsilon_max = 82
    
    # sensor_normalization 
    data['TEMP'] = sense_min_max_Normalization(data['TEMP'],temp_min,temp_max)
    data['EC'] = sense_min_max_Normalization(data['EC'],ec_min,ec_max)
    data['VWC'] = sense_min_max_Normalization(data['VWC'],vwc_min,vwc_max)
    data['TDS'] = sense_min_max_Normalization(data['TDS'],tds_min,tds_max)
    data['SALINITY'] = sense_min_max_Normalization(data['SALINITY'],salinity_min,salinity_max)
    data['EPSILON'] = sense_min_max_Normalization(data['EPSILON'],epsilon_min,epsilon_max)
    
    return data

# %%
### Load FDR Data

path_list = []
path_under=os.listdir(path_upper)

# Load data_path
for i in range(len(path_under)): # collect under directory file path
    path_sub=os.listdir(path_upper+'/'+path_under[i])
    
    for j in range(len(path_sub)):
        path_list.append(path_upper+'/'+path_under[i]+'/'+path_sub[j])

# Create the zero matrix
data_list = [0]*len(path_list)
rand_x_data_list = [0]*len(path_list)
rand_y_data_list = [0]*len(path_list)

# Load data_value
for i,j in enumerate(path_list):
    data_list[i] =pd.read_csv(j)
    data_list[i] = data_set_normalization(data_list[i])

# Create the entire dataset.
total_data = pd.concat(data_list)
total_data = total_data.dropna()

# Print the data format
total_data
# Out:
#      WC_ratio      TEMP       EC     VWC      TDS  SALINITY   EPSILON
# 0         0.4  0.523083  0.18250  0.6175  0.09125   0.10035  0.690366
# 1         0.4  0.520667  0.18320  0.6234  0.09160   0.10075  0.698902
# 2         0.4  0.519000  0.18435  0.6234  0.09215   0.10135  0.698902
# 3         0.4  0.517917  0.18755  0.6278  0.09375   0.10315  0.705244
# 4         0.4  0.517000  0.18830  0.6326  0.09415   0.10355  0.711829
# ..        ...       ...      ...     ...      ...       ...       ...
# 526       0.6  0.487667  0.29310  0.9488  0.14655   0.16120  0.967439
# 527       0.6  0.487667  0.29355  0.9488  0.14675   0.16145  0.967439
# 528       0.6  0.487667  0.29400  0.9488  0.14700   0.16170  0.967439
# 529       0.6  0.487667  0.29355  0.9488  0.14675   0.16145  0.967439
# 530       0.6  0.487667  0.29355  0.9488  0.14675   0.16145  0.967439
#
# [23350 rows x 7 columns]

# %%
# GT-label (WCR)
y_R = round(total_data['WC_ratio']*100, 1)
y_data_total = y_R.to_numpy()

# FDR sensor data
x_R = total_data[['TEMP','VWC','EPSILON','SALINITY','TDS','EC']]
x_data_total = x_R.to_numpy()

# %%
# split train/test data
tmp_x_train, x_test, tmp_y_train, y_test = train_test_split(x_data_total.astype('float'), y_data_total.astype('float'), test_size=0.2, random_state=seed_data)

# splot train/valid data
x_train_kfold = []
x_valid_kfold = []
y_train_kfold = []
y_valid_kfold = []

kfold = KFold(n_splits=k_fold_num)

for train_idx, valid_idx in kfold.split(tmp_x_train):
    x_train_kfold.append(tmp_x_train[train_idx])
    x_valid_kfold.append(tmp_x_train[valid_idx])
    y_train_kfold.append(tmp_y_train[train_idx])
    y_valid_kfold.append(tmp_y_train[valid_idx])

# Print the quantity of data
print(f"quantity of train data : {len(x_train_kfold[0])}")
print(f"quantity of validation data : {len(x_valid_kfold[0])}")
print(f"quantity of test data : {len(y_test)}")
# Out:
# quantity of train data : 14010
# quantity of validation data : 4670
# quantity of test data : 4670

# %%
### Create WCRnet

print("tf_version : %s" %tf.__version__)

def layer_1(x):    
    x = tf.keras.layers.Dense(32, kernel_initializer='normal')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
 
    return x   
 
    
def layer_2(x):       
 
    for i in range(layer_list[0]): 
        if i==0: 
            # upsample 32 -> 64
            reshaped_input = tf.expand_dims(x, axis=-1)
            upsampled_output = tf.keras.layers.UpSampling1D(size=2)(reshaped_input)
            shortcut = tf.squeeze(upsampled_output, axis=-1)            
        else:
            shortcut = x
            
        x = tf.keras.layers.Dense(64, kernel_initializer='normal')(x)     
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)
        
        x = tf.keras.layers.Dense(64, kernel_initializer='normal')(x)     
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)

        x = tf.keras.layers.Dense(64, kernel_initializer='normal')(x)     
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)
        
        x = tf.keras.layers.Add()([x, shortcut])
        x = tf.keras.activations.relu(x)

        shortcut = x
      
    return x
 
  
def layer_3(x):        
    
    for i in range(layer_list[1]):  
        if i==0: 
            # upsample 64 -> 128
            reshaped_input = tf.expand_dims(x, axis=-1)
            upsampled_output = tf.keras.layers.UpSampling1D(size=2)(reshaped_input)
            shortcut = tf.squeeze(upsampled_output, axis=-1)
        else:
            shortcut = x
            
        x = tf.keras.layers.Dense(128, kernel_initializer='normal')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)
    
        x = tf.keras.layers.Dense(128, kernel_initializer='normal')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)  

        x = tf.keras.layers.Dense(128, kernel_initializer='normal')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)  
        
        x = tf.keras.layers.Add()([x, shortcut])
        x = tf.keras.activations.relu(x)

        shortcut = x      
            
    return x
 
  
def layer_4(x):   
    
    for i in range(layer_list[2]): 
        if i==0: 
            # downsample 128 -> 64
            reshaped_input = tf.expand_dims(x, axis=-1)
            downsampled_output  = tf.keras.layers.AveragePooling1D(pool_size=2)(reshaped_input)
            shortcut = tf.squeeze(downsampled_output , axis=-1)
        else:
            shortcut = x
            
        x = tf.keras.layers.Dense(64, kernel_initializer='normal')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)
    
        x = tf.keras.layers.Dense(64, kernel_initializer='normal')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)  
    
        x = tf.keras.layers.Dense(64, kernel_initializer='normal')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)  
        
        x = tf.keras.layers.Add()([x, shortcut])
        x = tf.keras.activations.relu(x)

        shortcut = x      
            
    return x
 
  
def layer_5(x):
    
    for i in range(layer_list[3]):
        if i==0: 
            # downsample 64 -> 32
            reshaped_input = tf.expand_dims(x, axis=-1)
            downsampled_output  = tf.keras.layers.AveragePooling1D(pool_size=2)(reshaped_input)
            shortcut = tf.squeeze(downsampled_output , axis=-1)
        else:
            shortcut = x    

        x = tf.keras.layers.Dense(32, kernel_initializer='normal')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)
    
        x = tf.keras.layers.Dense(32, kernel_initializer='normal')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)  

        x = tf.keras.layers.Dense(32, kernel_initializer='normal')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)  
        
        x = tf.keras.layers.Add()([x, shortcut])
        x = tf.keras.activations.relu(x)

        shortcut = x      
            
    return x


def lr_exp_decay(epoch, lr):
    if epoch <50:
        return initial_learning_rate
    
    elif epoch >=50 and epoch <100:
        return initial_learning_rate * 0.1
    
    elif epoch >=100 and epoch <300:
        return initial_learning_rate * 0.01
    
    elif epoch >=300 and epoch <500:
        return initial_learning_rate * 0.001
    
    else:
        return initial_learning_rate * 0.0001
# Out:
# tf_version : 2.6.2

# %%
### Compile WCRnet

input_tensor =  tf.keras.Input(shape=(input_shape,))

x = layer_1(input_tensor)
x = layer_2(x)
x = layer_3(x)
x = layer_4(x)
x = layer_5(x)
 
output_tensor = tf.keras.layers.Dense(1, kernel_initializer='normal')(x)
output_tensor = tf.keras.activations.relu(output_tensor)

model = tf.keras.Model(input_tensor, output_tensor)
model.summary()

start_model=model.get_weights()
counter  = 0
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           224         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32)           128         dense[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu (TFOpLambda)         (None, 32)           0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           2112        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64)           256         dense_1[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_1 (TFOpLambda)       (None, 64)           0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           4160        tf.nn.relu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_2 (TFOpLambda)       (None, 64)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           4160        tf.nn.relu_2[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims (TFOpLambda)     (None, 32, 1)        0           tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# up_sampling1d (UpSampling1D)    (None, 64, 1)        0           tf.expand_dims[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_3 (TFOpLambda)       (None, 64)           0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.squeeze (TFOpLambd (None, 64)           0           up_sampling1d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64)           0           tf.nn.relu_3[0][0]
#                                                                  tf.compat.v1.squeeze[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_4 (TFOpLambda)       (None, 64)           0           add[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           4160        tf.nn.relu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64)           256         dense_4[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_5 (TFOpLambda)       (None, 64)           0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           4160        tf.nn.relu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64)           256         dense_5[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_6 (TFOpLambda)       (None, 64)           0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           4160        tf.nn.relu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64)           256         dense_6[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_7 (TFOpLambda)       (None, 64)           0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64)           0           tf.nn.relu_7[0][0]
#                                                                  tf.nn.relu_4[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_8 (TFOpLambda)       (None, 64)           0           add_1[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           4160        tf.nn.relu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64)           256         dense_7[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_9 (TFOpLambda)       (None, 64)           0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 64)           4160        tf.nn.relu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64)           256         dense_8[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_10 (TFOpLambda)      (None, 64)           0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 64)           4160        tf.nn.relu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64)           256         dense_9[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_11 (TFOpLambda)      (None, 64)           0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64)           0           tf.nn.relu_11[0][0]
#                                                                  tf.nn.relu_8[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_12 (TFOpLambda)      (None, 64)           0           add_2[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 128)          8320        tf.nn.relu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128)          512         dense_10[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_13 (TFOpLambda)      (None, 128)          0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 128)          16512       tf.nn.relu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128)          512         dense_11[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_14 (TFOpLambda)      (None, 128)          0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 128)          16512       tf.nn.relu_14[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_1 (TFOpLambda)   (None, 64, 1)        0           tf.nn.relu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 128)          512         dense_12[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_1 (UpSampling1D)  (None, 128, 1)       0           tf.expand_dims_1[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_15 (TFOpLambda)      (None, 128)          0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.squeeze_1 (TFOpLam (None, 128)          0           up_sampling1d_1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128)          0           tf.nn.relu_15[0][0]
#                                                                  tf.compat.v1.squeeze_1[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_16 (TFOpLambda)      (None, 128)          0           add_3[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 128)          16512       tf.nn.relu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 128)          512         dense_13[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_17 (TFOpLambda)      (None, 128)          0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 128)          16512       tf.nn.relu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128)          512         dense_14[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_18 (TFOpLambda)      (None, 128)          0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 128)          16512       tf.nn.relu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128)          512         dense_15[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_19 (TFOpLambda)      (None, 128)          0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128)          0           tf.nn.relu_19[0][0]
#                                                                  tf.nn.relu_16[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_20 (TFOpLambda)      (None, 128)          0           add_4[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 128)          16512       tf.nn.relu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128)          512         dense_16[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_21 (TFOpLambda)      (None, 128)          0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 128)          16512       tf.nn.relu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128)          512         dense_17[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_22 (TFOpLambda)      (None, 128)          0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 128)          16512       tf.nn.relu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128)          512         dense_18[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_23 (TFOpLambda)      (None, 128)          0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 128)          0           tf.nn.relu_23[0][0]
#                                                                  tf.nn.relu_20[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_24 (TFOpLambda)      (None, 128)          0           add_5[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 128)          16512       tf.nn.relu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 128)          512         dense_19[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_25 (TFOpLambda)      (None, 128)          0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 128)          16512       tf.nn.relu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 128)          512         dense_20[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_26 (TFOpLambda)      (None, 128)          0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 128)          16512       tf.nn.relu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 128)          512         dense_21[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_27 (TFOpLambda)      (None, 128)          0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 128)          0           tf.nn.relu_27[0][0]
#                                                                  tf.nn.relu_24[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_28 (TFOpLambda)      (None, 128)          0           add_6[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 64)           8256        tf.nn.relu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64)           256         dense_22[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_29 (TFOpLambda)      (None, 64)           0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 64)           4160        tf.nn.relu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 64)           256         dense_23[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_30 (TFOpLambda)      (None, 64)           0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 64)           4160        tf.nn.relu_30[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_2 (TFOpLambda)   (None, 128, 1)       0           tf.nn.relu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64)           256         dense_24[0][0]
# __________________________________________________________________________________________________
# average_pooling1d (AveragePooli (None, 64, 1)        0           tf.expand_dims_2[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_31 (TFOpLambda)      (None, 64)           0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.squeeze_2 (TFOpLam (None, 64)           0           average_pooling1d[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64)           0           tf.nn.relu_31[0][0]
#                                                                  tf.compat.v1.squeeze_2[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_32 (TFOpLambda)      (None, 64)           0           add_7[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 64)           4160        tf.nn.relu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 64)           256         dense_25[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_33 (TFOpLambda)      (None, 64)           0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 64)           4160        tf.nn.relu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 64)           256         dense_26[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_34 (TFOpLambda)      (None, 64)           0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 64)           4160        tf.nn.relu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 64)           256         dense_27[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_35 (TFOpLambda)      (None, 64)           0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 64)           0           tf.nn.relu_35[0][0]
#                                                                  tf.nn.relu_32[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_36 (TFOpLambda)      (None, 64)           0           add_8[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 64)           4160        tf.nn.relu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 64)           256         dense_28[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_37 (TFOpLambda)      (None, 64)           0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 64)           4160        tf.nn.relu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 64)           256         dense_29[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_38 (TFOpLambda)      (None, 64)           0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 64)           4160        tf.nn.relu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 64)           256         dense_30[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_39 (TFOpLambda)      (None, 64)           0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64)           0           tf.nn.relu_39[0][0]
#                                                                  tf.nn.relu_36[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_40 (TFOpLambda)      (None, 64)           0           add_9[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 64)           4160        tf.nn.relu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 64)           256         dense_31[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_41 (TFOpLambda)      (None, 64)           0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 64)           4160        tf.nn.relu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 64)           256         dense_32[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_42 (TFOpLambda)      (None, 64)           0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 64)           4160        tf.nn.relu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 64)           256         dense_33[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_43 (TFOpLambda)      (None, 64)           0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 64)           0           tf.nn.relu_43[0][0]
#                                                                  tf.nn.relu_40[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_44 (TFOpLambda)      (None, 64)           0           add_10[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 64)           4160        tf.nn.relu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 64)           256         dense_34[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_45 (TFOpLambda)      (None, 64)           0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 64)           4160        tf.nn.relu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 64)           256         dense_35[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_46 (TFOpLambda)      (None, 64)           0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 64)           4160        tf.nn.relu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 64)           256         dense_36[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_47 (TFOpLambda)      (None, 64)           0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 64)           0           tf.nn.relu_47[0][0]
#                                                                  tf.nn.relu_44[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_48 (TFOpLambda)      (None, 64)           0           add_11[0][0]
# __________________________________________________________________________________________________
# dense_37 (Dense)                (None, 64)           4160        tf.nn.relu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 64)           256         dense_37[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_49 (TFOpLambda)      (None, 64)           0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# dense_38 (Dense)                (None, 64)           4160        tf.nn.relu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 64)           256         dense_38[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_50 (TFOpLambda)      (None, 64)           0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# dense_39 (Dense)                (None, 64)           4160        tf.nn.relu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 64)           256         dense_39[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_51 (TFOpLambda)      (None, 64)           0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 64)           0           tf.nn.relu_51[0][0]
#                                                                  tf.nn.relu_48[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_52 (TFOpLambda)      (None, 64)           0           add_12[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 64)           4160        tf.nn.relu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 64)           256         dense_40[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_53 (TFOpLambda)      (None, 64)           0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 64)           4160        tf.nn.relu_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 64)           256         dense_41[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_54 (TFOpLambda)      (None, 64)           0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 64)           4160        tf.nn.relu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 64)           256         dense_42[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_55 (TFOpLambda)      (None, 64)           0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64)           0           tf.nn.relu_55[0][0]
#                                                                  tf.nn.relu_52[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_56 (TFOpLambda)      (None, 64)           0           add_13[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 64)           4160        tf.nn.relu_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 64)           256         dense_43[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_57 (TFOpLambda)      (None, 64)           0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 64)           4160        tf.nn.relu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 64)           256         dense_44[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_58 (TFOpLambda)      (None, 64)           0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 64)           4160        tf.nn.relu_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 64)           256         dense_45[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_59 (TFOpLambda)      (None, 64)           0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 64)           0           tf.nn.relu_59[0][0]
#                                                                  tf.nn.relu_56[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_60 (TFOpLambda)      (None, 64)           0           add_14[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 64)           4160        tf.nn.relu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 64)           256         dense_46[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_61 (TFOpLambda)      (None, 64)           0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 64)           4160        tf.nn.relu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 64)           256         dense_47[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_62 (TFOpLambda)      (None, 64)           0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# dense_48 (Dense)                (None, 64)           4160        tf.nn.relu_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 64)           256         dense_48[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_63 (TFOpLambda)      (None, 64)           0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 64)           0           tf.nn.relu_63[0][0]
#                                                                  tf.nn.relu_60[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_64 (TFOpLambda)      (None, 64)           0           add_15[0][0]
# __________________________________________________________________________________________________
# dense_49 (Dense)                (None, 64)           4160        tf.nn.relu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 64)           256         dense_49[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_65 (TFOpLambda)      (None, 64)           0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# dense_50 (Dense)                (None, 64)           4160        tf.nn.relu_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 64)           256         dense_50[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_66 (TFOpLambda)      (None, 64)           0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# dense_51 (Dense)                (None, 64)           4160        tf.nn.relu_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 64)           256         dense_51[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_67 (TFOpLambda)      (None, 64)           0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 64)           0           tf.nn.relu_67[0][0]
#                                                                  tf.nn.relu_64[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_68 (TFOpLambda)      (None, 64)           0           add_16[0][0]
# __________________________________________________________________________________________________
# dense_52 (Dense)                (None, 64)           4160        tf.nn.relu_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 64)           256         dense_52[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_69 (TFOpLambda)      (None, 64)           0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# dense_53 (Dense)                (None, 64)           4160        tf.nn.relu_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 64)           256         dense_53[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_70 (TFOpLambda)      (None, 64)           0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# dense_54 (Dense)                (None, 64)           4160        tf.nn.relu_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 64)           256         dense_54[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_71 (TFOpLambda)      (None, 64)           0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 64)           0           tf.nn.relu_71[0][0]
#                                                                  tf.nn.relu_68[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_72 (TFOpLambda)      (None, 64)           0           add_17[0][0]
# __________________________________________________________________________________________________
# dense_55 (Dense)                (None, 64)           4160        tf.nn.relu_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 64)           256         dense_55[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_73 (TFOpLambda)      (None, 64)           0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# dense_56 (Dense)                (None, 64)           4160        tf.nn.relu_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 64)           256         dense_56[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_74 (TFOpLambda)      (None, 64)           0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# dense_57 (Dense)                (None, 64)           4160        tf.nn.relu_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 64)           256         dense_57[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_75 (TFOpLambda)      (None, 64)           0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 64)           0           tf.nn.relu_75[0][0]
#                                                                  tf.nn.relu_72[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_76 (TFOpLambda)      (None, 64)           0           add_18[0][0]
# __________________________________________________________________________________________________
# dense_58 (Dense)                (None, 64)           4160        tf.nn.relu_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 64)           256         dense_58[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_77 (TFOpLambda)      (None, 64)           0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# dense_59 (Dense)                (None, 64)           4160        tf.nn.relu_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 64)           256         dense_59[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_78 (TFOpLambda)      (None, 64)           0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# dense_60 (Dense)                (None, 64)           4160        tf.nn.relu_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 64)           256         dense_60[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_79 (TFOpLambda)      (None, 64)           0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# ...
# dense_81 (Dense)                (None, 64)           4160        tf.nn.relu_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 64)           256         dense_81[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_107 (TFOpLambda)     (None, 64)           0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 64)           0           tf.nn.relu_107[0][0]
#                                                                  tf.nn.relu_104[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_108 (TFOpLambda)     (None, 64)           0           add_26[0][0]
# __________________________________________________________________________________________________
# dense_82 (Dense)                (None, 64)           4160        tf.nn.relu_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 64)           256         dense_82[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_109 (TFOpLambda)     (None, 64)           0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# dense_83 (Dense)                (None, 64)           4160        tf.nn.relu_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 64)           256         dense_83[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_110 (TFOpLambda)     (None, 64)           0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# dense_84 (Dense)                (None, 64)           4160        tf.nn.relu_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 64)           256         dense_84[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_111 (TFOpLambda)     (None, 64)           0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 64)           0           tf.nn.relu_111[0][0]
#                                                                  tf.nn.relu_108[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_112 (TFOpLambda)     (None, 64)           0           add_27[0][0]
# __________________________________________________________________________________________________
# dense_85 (Dense)                (None, 64)           4160        tf.nn.relu_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 64)           256         dense_85[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_113 (TFOpLambda)     (None, 64)           0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# dense_86 (Dense)                (None, 64)           4160        tf.nn.relu_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 64)           256         dense_86[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_114 (TFOpLambda)     (None, 64)           0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# dense_87 (Dense)                (None, 64)           4160        tf.nn.relu_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 64)           256         dense_87[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_115 (TFOpLambda)     (None, 64)           0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 64)           0           tf.nn.relu_115[0][0]
#                                                                  tf.nn.relu_112[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_116 (TFOpLambda)     (None, 64)           0           add_28[0][0]
# __________________________________________________________________________________________________
# dense_88 (Dense)                (None, 64)           4160        tf.nn.relu_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 64)           256         dense_88[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_117 (TFOpLambda)     (None, 64)           0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# dense_89 (Dense)                (None, 64)           4160        tf.nn.relu_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 64)           256         dense_89[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_118 (TFOpLambda)     (None, 64)           0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# dense_90 (Dense)                (None, 64)           4160        tf.nn.relu_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 64)           256         dense_90[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_119 (TFOpLambda)     (None, 64)           0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 64)           0           tf.nn.relu_119[0][0]
#                                                                  tf.nn.relu_116[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_120 (TFOpLambda)     (None, 64)           0           add_29[0][0]
# __________________________________________________________________________________________________
# dense_91 (Dense)                (None, 32)           2080        tf.nn.relu_120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 32)           128         dense_91[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_121 (TFOpLambda)     (None, 32)           0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# dense_92 (Dense)                (None, 32)           1056        tf.nn.relu_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 32)           128         dense_92[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_122 (TFOpLambda)     (None, 32)           0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# dense_93 (Dense)                (None, 32)           1056        tf.nn.relu_122[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_3 (TFOpLambda)   (None, 64, 1)        0           tf.nn.relu_120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 32)           128         dense_93[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_1 (AveragePoo (None, 32, 1)        0           tf.expand_dims_3[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_123 (TFOpLambda)     (None, 32)           0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.squeeze_3 (TFOpLam (None, 32)           0           average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 32)           0           tf.nn.relu_123[0][0]
#                                                                  tf.compat.v1.squeeze_3[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_124 (TFOpLambda)     (None, 32)           0           add_30[0][0]
# __________________________________________________________________________________________________
# dense_94 (Dense)                (None, 32)           1056        tf.nn.relu_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 32)           128         dense_94[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_125 (TFOpLambda)     (None, 32)           0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# dense_95 (Dense)                (None, 32)           1056        tf.nn.relu_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 32)           128         dense_95[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_126 (TFOpLambda)     (None, 32)           0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# dense_96 (Dense)                (None, 32)           1056        tf.nn.relu_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 32)           128         dense_96[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_127 (TFOpLambda)     (None, 32)           0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 32)           0           tf.nn.relu_127[0][0]
#                                                                  tf.nn.relu_124[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_128 (TFOpLambda)     (None, 32)           0           add_31[0][0]
# __________________________________________________________________________________________________
# dense_97 (Dense)                (None, 32)           1056        tf.nn.relu_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 32)           128         dense_97[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_129 (TFOpLambda)     (None, 32)           0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# dense_98 (Dense)                (None, 32)           1056        tf.nn.relu_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 32)           128         dense_98[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_130 (TFOpLambda)     (None, 32)           0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# dense_99 (Dense)                (None, 32)           1056        tf.nn.relu_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 32)           128         dense_99[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_131 (TFOpLambda)     (None, 32)           0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 32)           0           tf.nn.relu_131[0][0]
#                                                                  tf.nn.relu_128[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_132 (TFOpLambda)     (None, 32)           0           add_32[0][0]
# __________________________________________________________________________________________________
# dense_100 (Dense)               (None, 1)            33          tf.nn.relu_132[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_133 (TFOpLambda)     (None, 1)            0           dense_100[0][0]
# ==================================================================================================
# Total params: 554,657
# Trainable params: 540,961
# Non-trainable params: 13,696
# __________________________________________________________________________________________________

# %%
### Training WCRnet

train_mode = True

if train_mode == True:
    # Load the learning rate scheduler
    lr_s = tf.keras.callbacks.LearningRateScheduler(lr_exp_decay)

    # Load the Early Stopping
    early_stop = tf.keras.callbacks.EarlyStopping(patience=300, min_delta=3, monitor='val_loss')    
    
    # model compile
    model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam())

    # training
    history = model.fit(x_train_kfold[current_fold], y_train_kfold[current_fold], validation_data=(x_valid_kfold[current_fold], y_valid_kfold[current_fold]), epochs=epochs, batch_size=batch_sizes, callbacks=[lr_s, early_stop])

    # save WCRnet
    model.save(last_model_save_dir)
# Out:
# Epoch 1/1000
# 14/14 [==============================] - 22s 344ms/step - loss: 437.1411 - val_loss: 2534.4153
# Epoch 2/1000
# 14/14 [==============================] - 3s 216ms/step - loss: 5.0099 - val_loss: 2534.4153
# Epoch 3/1000
# 14/14 [==============================] - 3s 193ms/step - loss: 3.8749 - val_loss: 2534.4153
# Epoch 4/1000
# 14/14 [==============================] - 3s 204ms/step - loss: 3.7710 - val_loss: 2534.4153
# Epoch 5/1000
# 14/14 [==============================] - 3s 209ms/step - loss: 4.7331 - val_loss: 2534.4153
# Epoch 6/1000
# 14/14 [==============================] - 3s 196ms/step - loss: 3.9862 - val_loss: 2534.4153
# Epoch 7/1000
# 14/14 [==============================] - 3s 191ms/step - loss: 4.5939 - val_loss: 2534.4153
# Epoch 8/1000
# 14/14 [==============================] - 3s 191ms/step - loss: 4.8728 - val_loss: 2502.5571
# Epoch 9/1000
# 14/14 [==============================] - 3s 194ms/step - loss: 3.3861 - val_loss: 750.7649
# Epoch 10/1000
# 14/14 [==============================] - 3s 204ms/step - loss: 5.3920 - val_loss: 902.4880
# Epoch 11/1000
# 14/14 [==============================] - 3s 203ms/step - loss: 5.5813 - val_loss: 55.0750
# Epoch 12/1000
# 14/14 [==============================] - 3s 186ms/step - loss: 3.9873 - val_loss: 47.5941
# Epoch 13/1000
# 14/14 [==============================] - 3s 195ms/step - loss: 4.4641 - val_loss: 51.4864
# Epoch 14/1000
# 14/14 [==============================] - 3s 202ms/step - loss: 4.6300 - val_loss: 32.8547
# Epoch 15/1000
# 14/14 [==============================] - 2s 165ms/step - loss: 5.0257 - val_loss: 26.0156
# Epoch 16/1000
# 14/14 [==============================] - 2s 182ms/step - loss: 5.2508 - val_loss: 33.6077
# Epoch 17/1000
# 14/14 [==============================] - 3s 181ms/step - loss: 6.4639 - val_loss: 33.7350
# Epoch 18/1000
# 14/14 [==============================] - 3s 191ms/step - loss: 3.3677 - val_loss: 32.0156
# Epoch 19/1000
# 14/14 [==============================] - 3s 198ms/step - loss: 3.8535 - val_loss: 14.1475
# Epoch 20/1000
# 14/14 [==============================] - 3s 202ms/step - loss: 4.4288 - val_loss: 13.5790
# Epoch 21/1000
# 14/14 [==============================] - 3s 214ms/step - loss: 2.9782 - val_loss: 15.0321
# Epoch 22/1000
# 14/14 [==============================] - 3s 209ms/step - loss: 3.8461 - val_loss: 7.9870
# Epoch 23/1000
# 14/14 [==============================] - 3s 181ms/step - loss: 6.9845 - val_loss: 14.7050
# Epoch 24/1000
# 14/14 [==============================] - 3s 196ms/step - loss: 4.0887 - val_loss: 28.6061
# Epoch 25/1000
# 14/14 [==============================] - 3s 204ms/step - loss: 5.9679 - val_loss: 16.3159
# Epoch 26/1000
# 14/14 [==============================] - 3s 189ms/step - loss: 3.0422 - val_loss: 9.2997
# Epoch 27/1000
# 14/14 [==============================] - 3s 184ms/step - loss: 2.8733 - val_loss: 8.5440
# Epoch 28/1000
# 14/14 [==============================] - 2s 178ms/step - loss: 2.7902 - val_loss: 8.7234
# Epoch 29/1000
# 14/14 [==============================] - 3s 181ms/step - loss: 3.1072 - val_loss: 8.2648
# Epoch 30/1000
# 14/14 [==============================] - 3s 202ms/step - loss: 3.2688 - val_loss: 8.7402
# Epoch 31/1000
# 14/14 [==============================] - 3s 206ms/step - loss: 3.0692 - val_loss: 8.4049
# Epoch 32/1000
# 14/14 [==============================] - 3s 201ms/step - loss: 4.3466 - val_loss: 10.9249
# Epoch 33/1000
# 14/14 [==============================] - 3s 204ms/step - loss: 3.5521 - val_loss: 8.8896
# Epoch 34/1000
# 14/14 [==============================] - 3s 195ms/step - loss: 2.7096 - val_loss: 10.2838
# Epoch 35/1000
# 14/14 [==============================] - 3s 213ms/step - loss: 4.0026 - val_loss: 13.5221
# Epoch 36/1000
# 14/14 [==============================] - 3s 196ms/step - loss: 3.9762 - val_loss: 29.3934
# Epoch 37/1000
# 14/14 [==============================] - 3s 202ms/step - loss: 5.6862 - val_loss: 14.7843
# Epoch 38/1000
# 14/14 [==============================] - 3s 214ms/step - loss: 4.3782 - val_loss: 13.5095
# Epoch 39/1000
# 14/14 [==============================] - 3s 202ms/step - loss: 3.1434 - val_loss: 15.0877
# Epoch 40/1000
# 14/14 [==============================] - 3s 189ms/step - loss: 2.4168 - val_loss: 19.4782
# Epoch 41/1000
# 14/14 [==============================] - 3s 201ms/step - loss: 3.1114 - val_loss: 12.9985
# Epoch 42/1000
# 14/14 [==============================] - 3s 202ms/step - loss: 2.7602 - val_loss: 12.7685
# Epoch 43/1000
# 14/14 [==============================] - 3s 208ms/step - loss: 2.3246 - val_loss: 12.1065
# Epoch 44/1000
# 14/14 [==============================] - 3s 196ms/step - loss: 2.6759 - val_loss: 16.8955
# Epoch 45/1000
# 14/14 [==============================] - 3s 185ms/step - loss: 2.4293 - val_loss: 15.6261
# Epoch 46/1000
# 14/14 [==============================] - 2s 174ms/step - loss: 3.4274 - val_loss: 22.5569
# Epoch 47/1000
# 14/14 [==============================] - 2s 171ms/step - loss: 2.6378 - val_loss: 21.0320
# Epoch 48/1000
# 14/14 [==============================] - 2s 178ms/step - loss: 2.9593 - val_loss: 33.5545
# Epoch 49/1000
# 14/14 [==============================] - 3s 179ms/step - loss: 2.4306 - val_loss: 91.5199
# Epoch 50/1000
# 14/14 [==============================] - 3s 189ms/step - loss: 3.0756 - val_loss: 101.6482
# Epoch 51/1000
# 14/14 [==============================] - 3s 188ms/step - loss: 1.9897 - val_loss: 95.2916
# Epoch 52/1000
# 14/14 [==============================] - 3s 204ms/step - loss: 1.8297 - val_loss: 87.6255
# Epoch 53/1000
# 14/14 [==============================] - 3s 196ms/step - loss: 1.8303 - val_loss: 75.1104
# Epoch 54/1000
# 14/14 [==============================] - 3s 199ms/step - loss: 1.8597 - val_loss: 69.4629
# Epoch 55/1000
# 14/14 [==============================] - 3s 200ms/step - loss: 1.7992 - val_loss: 68.6764
# Epoch 56/1000
# 14/14 [==============================] - 3s 210ms/step - loss: 1.8119 - val_loss: 67.5033
# Epoch 57/1000
# 14/14 [==============================] - 3s 199ms/step - loss: 1.8742 - val_loss: 59.5196
# Epoch 58/1000
# 14/14 [==============================] - 3s 215ms/step - loss: 1.9247 - val_loss: 52.0429
# Epoch 59/1000
# 14/14 [==============================] - 3s 191ms/step - loss: 1.7808 - val_loss: 46.6945
# Epoch 60/1000
# 14/14 [==============================] - 3s 201ms/step - loss: 1.7141 - val_loss: 41.1911
# Epoch 61/1000
# 14/14 [==============================] - 3s 218ms/step - loss: 1.7141 - val_loss: 30.6005
# Epoch 62/1000
# 14/14 [==============================] - 3s 197ms/step - loss: 1.7764 - val_loss: 26.4360
# Epoch 63/1000
# 14/14 [==============================] - 3s 212ms/step - loss: 1.7312 - val_loss: 21.4130
# Epoch 64/1000
# 14/14 [==============================] - 3s 219ms/step - loss: 1.7592 - val_loss: 13.7603
# Epoch 65/1000
# 14/14 [==============================] - 3s 199ms/step - loss: 1.7344 - val_loss: 11.0111
# Epoch 66/1000
# 14/14 [==============================] - 3s 197ms/step - loss: 1.6421 - val_loss: 9.2740
# Epoch 67/1000
# 14/14 [==============================] - 3s 184ms/step - loss: 1.7614 - val_loss: 11.7620
# Epoch 68/1000
# 14/14 [==============================] - 3s 213ms/step - loss: 1.7054 - val_loss: 15.7226
# Epoch 69/1000
# 14/14 [==============================] - 3s 199ms/step - loss: 1.8297 - val_loss: 13.0333
# Epoch 70/1000
# 14/14 [==============================] - 3s 215ms/step - loss: 1.7537 - val_loss: 7.3747
# Epoch 71/1000
# 14/14 [==============================] - 3s 201ms/step - loss: 1.7901 - val_loss: 3.1599
# Epoch 72/1000
# 14/14 [==============================] - 3s 197ms/step - loss: 1.7503 - val_loss: 3.3970
# Epoch 73/1000
# 14/14 [==============================] - 3s 193ms/step - loss: 1.8094 - val_loss: 2.6081
# Epoch 74/1000
# 14/14 [==============================] - 3s 199ms/step - loss: 1
1000
# 14/14 [==============================] - 3s 195ms/step - loss: 1.6770 - val_loss: 2.3226
# Epoch 115/1000
# 14/14 [==============================] - 3s 193ms/step - loss: 1.6731 - val_loss: 2.1921
# Epoch 116/1000
# 14/14 [==============================] - 3s 186ms/step - loss: 1.5341 - val_loss: 1.9102
# Epoch 117/1000
# 14/14 [==============================] - 3s 209ms/step - loss: 1.5678 - val_loss: 1.9562
# Epoch 118/1000
# 14/14 [==============================] - 3s 207ms/step - loss: 1.5506 - val_loss: 2.0222
# Epoch 119/1000
# 14/14 [==============================] - 3s 204ms/step - loss: 1.5603 - val_loss: 2.0325
# Epoch 120/1000
# 14/14 [==============================] - 3s 201ms/step - loss: 1.5357 - val_loss: 2.0254
# Epoch 121/1000
# 14/14 [==============================] - 3s 209ms/step - loss: 1.5585 - val_loss: 2.0071
# Epoch 122/1000
# 14/14 [==============================] - 3s 194ms/step - loss: 1.4482 - val_loss: 1.9930
# Epoch 123/1000
# 14/14 [==============================] - 2s 178ms/step - loss: 1.5128 - val_loss: 1.9550
# Epoch 124/1000
# 14/14 [==============================] - 3s 194ms/step - loss: 1.5961 - val_loss: 1.7280
# Epoch 125/1000
# 14/14 [==============================] - 3s 198ms/step - loss: 1.6401 - val_loss: 1.6591
# Epoch 126/1000
# 14/14 [==============================] - 3s 214ms/step - loss: 1.5271 - val_loss: 1.7079
# Epoch 127/1000
# 14/14 [==============================] - 3s 198ms/step - loss: 1.5241 - val_loss: 1.6478
# Epoch 128/1000
# 14/14 [==============================] - 3s 194ms/step - loss: 1.5496 - val_loss: 1.6010
# Epoch 129/1000
# 14/14 [==============================] - 3s 207ms/step - loss: 1.5745 - val_loss: 1.5726
# Epoch 130/1000
# 14/14 [==============================] - 3s 200ms/step - loss: 1.4732 - val_loss: 1.5422
# Epoch 131/1000
# 14/14 [==============================] - 3s 185ms/step - loss: 1.5190 - val_loss: 1.5971
# Epoch 132/1000
# 14/14 [==============================] - 3s 193ms/step - loss: 1.5861 - val_loss: 1.5805
# Epoch 133/1000
# 14/14 [==============================] - 3s 201ms/step - loss: 1.5820 - val_loss: 1.5471
# Epoch 134/1000
# 14/14 [==============================] - 3s 183ms/step - loss: 1.5236 - val_loss: 1.5739
# Epoch 135/1000
# 14/14 [==============================] - 3s 191ms/step - loss: 1.6231 - val_loss: 1.5962
# Epoch 136/1000
# 14/14 [==============================] - 3s 221ms/step - loss: 1.5270 - val_loss: 1.5395
# Epoch 137/1000
# 14/14 [==============================] - 3s 211ms/step - loss: 1.5735 - val_loss: 1.6960
# Epoch 138/1000
# 14/14 [==============================] - 3s 192ms/step - loss: 1.5069 - val_loss: 1.7914
# Epoch 139/1000
# 14/14 [==============================] - 3s 202ms/step - loss: 1.5555 - val_loss: 1.6705
# Epoch 140/1000
# 14/14 [==============================] - 3s 201ms/step - loss: 1.6302 - val_loss: 1.5399
# Epoch 141/1000
# 14/14 [==============================] - 3s 193ms/step - loss: 1.5047 - val_loss: 1.6297
# Epoch 142/1000
# 14/14 [==============================] - 3s 187ms/step - loss: 1.4981 - val_loss: 1.6862
# Epoch 143/1000
# 14/14 [==============================] - 3s 201ms/step - loss: 1.4715 - val_loss: 1.6075
# Epoch 144/1000
# 14/14 [==============================] - 3s 193ms/step - loss: 1.4761 - val_loss: 1.5859
# Epoch 145/1000
# 14/14 [==============================] - 3s 183ms/step - loss: 1.4606 - val_loss: 1.5689
# Epoch 146/1000
# 14/14 [==============================] - 3s 199ms/step - loss: 1.5276 - val_loss: 1.5569
# Epoch 147/1000
# 14/14 [==============================] - 3s 195ms/step - loss: 1.5812 - val_loss: 1.5405
# Epoch 148/1000
# 14/14 [==============================] - 3s 207ms/step - loss: 1.5399 - val_loss: 1.5169
# Epoch 149/1000
# 14/14 [==============================] - 3s 188ms/step - loss: 1.5125 - val_loss: 1.6006
# Epoch 150/1000
# 14/14 [==============================] - 3s 197ms/step - loss: 1
1000
# 14/14 [==============================] - 3s 203ms/step - loss: 1.4374 - val_loss: 1.7634
# Epoch 185/1000
# 14/14 [==============================] - 3s 205ms/step - loss: 1.4961 - val_loss: 1.6419
# Epoch 186/1000
# 14/14 [==============================] - 3s 205ms/step - loss: 1.5017 - val_loss: 1.7243
# Epoch 187/1000
# 14/14 [==============================] - 2s 176ms/step - loss: 1.6049 - val_loss: 1.8935
# Epoch 188/1000
# 14/14 [==============================] - 3s 195ms/step - loss: 1.4476 - val_loss: 1.8803
# Epoch 189/1000
# 14/14 [==============================] - 3s 185ms/step - loss: 1.4877 - val_loss: 1.9502
# Epoch 190/1000
# 14/14 [==============================] - 3s 201ms/step - loss: 1.5389 - val_loss: 1.9314
# Epoch 191/1000
# 14/14 [==============================] - 3s 197ms/step - loss: 1.4601 - val_loss: 1.6813
# Epoch 192/1000
# 14/14 [==============================] - 3s 183ms/step - loss: 1.4276 - val_loss: 1.4919
# Epoch 193/1000
# 14/14 [==============================] - 2s 172ms/step - loss: 1.4830 - val_loss: 1.5045
# Epoch 194/1000
# 14/14 [==============================] - 3s 196ms/step - loss: 1.4660 - val_loss: 1.6211
# Epoch 195/1000
# 14/14 [==============================] - 3s 200ms/step - loss: 1.4997 - val_loss: 1.5598
# Epoch 196/1000
# 14/14 [==============================] - 3s 203ms/step - loss: 1.4356 - val_loss: 1.6681
# Epoch 197/1000
# 14/14 [==============================] - 3s 184ms/step - loss: 1.4932 - val_loss: 1.5775
# Epoch 198/1000
# 14/14 [==============================] - 3s 201ms/step - loss: 1.4547 - val_loss: 1.5238
# Epoch 199/1000
# 14/14 [==============================] - 3s 180ms/step - loss: 1.5046 - val_loss: 1.6807
# Epoch 200/1000
# 14/14 [==============================] - 2s 174ms/step - loss: 1.4810 - val_loss: 1.8469
# Epoch 201/1000
# 14/14 [==============================] - 3s 209ms/step - loss: 1.4541 - val_loss: 1.6026
# Epoch 202/1000
# 14/14 [==============================] - 3s 194ms/step - loss: 1.4635 - val_loss: 1.9800
# Epoch 203/1000
# 14/14 [==============================] - 3s 193ms/step - loss: 1.5439 - val_loss: 2.7207
# Epoch 204/1000
# 14/14 [==============================] - 3s 198ms/step - loss: 1.4802 - val_loss: 1.9332
# Epoch 205/1000
# 14/14 [==============================] - 3s 211ms/step - loss: 1.4652 - val_loss: 2.6339
# Epoch 206/1000
# 14/14 [==============================] - 3s 218ms/step - loss: 1.5070 - val_loss: 2.2276
# Epoch 207/1000
# 14/14 [==============================] - 3s 191ms/step - loss: 1.5028 - val_loss: 1.8878
# Epoch 208/1000
# 14/14 [==============================] - 3s 199ms/step - loss: 1.5171 - val_loss: 1.8433
# Epoch 209/1000
# 14/14 [==============================] - 3s 189ms/step - loss: 1.4343 - val_loss: 1.8945
# Epoch 210/1000
# 14/14 [==============================] - 3s 203ms/step - loss: 1.3805 - val_loss: 1.7354
# Epoch 211/1000
# 14/14 [==============================] - 3s 204ms/step - loss: 1.4752 - val_loss: 1.4698
# Epoch 212/1000
# 14/14 [==============================] - 3s 214ms/step - loss: 1.5298 - val_loss: 1.5366
# Epoch 213/1000
# 14/14 [==============================] - 3s 195ms/step - loss: 1.4158 - val_loss: 1.7349
# Epoch 214/1000
# 14/14 [==============================] - 3s 200ms/step - loss: 1.4299 - val_loss: 1.5003
# Epoch 215/1000
# 14/14 [==============================] - 3s 213ms/step - loss: 1.4871 - val_loss: 1.6637
# Epoch 216/1000
# 14/14 [==============================] - 3s 198ms/step - loss: 1.5111 - val_loss: 1.5674
# Epoch 217/1000
# 14/14 [==============================] - 3s 185ms/step - loss: 1.3930 - val_loss: 1.8091
# Epoch 218/1000
# 14/14 [==============================] - 3s 194ms/step - loss: 1.4658 - val_loss: 2.2372
# Epoch 219/1000
# 14/14 [==============================] - 3s 203ms/step - loss: 1.5302 - val_loss: 1.9331
# Epoch 220/1000
# 14/14 [==============================] - 3s 202ms/step - loss: 1.5187 - val_loss: 2.4896
# Epoch 221/1000
# 14/14 [==============================] - 3s 199ms/step - loss: 1.4556 - val_loss: 2.7513
# Epoch 222/1000
# 14/14 [==============================] - 3s 191ms/step - loss: 1.4361 - val_loss: 2.1619
# Epoch 223/1000
# 14/14 [==============================] - 2s 177ms/step - loss: 1.5014 - val_loss: 2.2928
# Epoch 224/1000
# 14/14 [==============================] - 3s 193ms/step - loss: 1
# Epoch 261/1000
# 14/14 [==============================] - 3s 208ms/step - loss: 1.3381 - val_loss: 4.1326
# Epoch 262/1000
# 14/14 [==============================] - 3s 192ms/step - loss: 1.3395 - val_loss: 4.0453
# Epoch 263/1000
# 14/14 [==============================] - 2s 174ms/step - loss: 1.3613 - val_loss: 3.5483
# Epoch 264/1000
# 14/14 [==============================] - 2s 178ms/step - loss: 1.3566 - val_loss: 2.6156
# Epoch 265/1000
# 14/14 [==============================] - 3s 200ms/step - loss: 1.4012 - val_loss: 3.1907
# Epoch 266/1000
# 14/14 [==============================] - 3s 188ms/step - loss: 1.4408 - val_loss: 3.4353
# Epoch 267/1000
# 14/14 [==============================] - 3s 181ms/step - loss: 1.5085 - val_loss: 3.0264
# Epoch 268/1000
# 14/14 [==============================] - 3s 188ms/step - loss: 1.3160 - val_loss: 3.0844
# Epoch 269/1000
# 14/14 [==============================] - 3s 217ms/step - loss: 1.4861 - val_loss: 3.2509
# Epoch 270/1000
# 14/14 [==============================] - 3s 212ms/step - loss: 1.3988 - val_loss: 2.8791
# Epoch 271/1000
# 14/14 [==============================] - 3s 210ms/step - loss: 1.3370 - val_loss: 2.5091
# Epoch 272/1000
# 14/14 [==============================] - 3s 201ms/step - loss: 1.5296 - val_loss: 1.7886
# Epoch 273/1000
# 14/14 [==============================] - 3s 214ms/step - loss: 1.3781 - val_loss: 2.0147
# Epoch 274/1000
# 14/14 [==============================] - 3s 181ms/step - loss: 1.2973 - val_loss: 2.0209
# Epoch 275/1000
# 14/14 [==============================] - 3s 211ms/step - loss: 1.3358 - val_loss: 1.5544
# Epoch 276/1000
# 14/14 [==============================] - 3s 199ms/step - loss: 1.3245 - val_loss: 1.5419
# Epoch 277/1000
# 14/14 [==============================] - 3s 203ms/step - loss: 1.3574 - val_loss: 2.0995
# Epoch 278/1000
# 14/14 [==============================] - 2s 175ms/step - loss: 1.2875 - val_loss: 2.0116
# Epoch 279/1000
# 14/14 [==============================] - 3s 185ms/step - loss: 1.4259 - val_loss: 2.1201
# Epoch 280/1000
# 14/14 [==============================] - 3s 204ms/step - loss: 1.2835 - val_loss: 2.1412
# Epoch 281/1000
# 14/14 [==============================] - 3s 209ms/step - loss: 1.3491 - val_loss: 1.9295
# Epoch 282/1000
# 14/14 [==============================] - 3s 196ms/step - loss: 1.3563 - val_loss: 2.0156
# Epoch 283/1000
# 14/14 [==============================] - 3s 203ms/step - loss: 1.3760 - val_loss: 2.2401
# Epoch 284/1000
# 14/14 [==============================] - 3s 180ms/step - loss: 1.3301 - val_loss: 2.0422
# Epoch 285/1000
# 14/14 [==============================] - 3s 182ms/step - loss: 1.3667 - val_loss: 2.1605
# Epoch 286/1000
# 14/14 [==============================] - 3s 205ms/step - loss: 1.3743 - val_loss: 1.9592
# Epoch 287/1000
# 14/14 [==============================] - 3s 184ms/step - loss: 1.3125 - val_loss: 1.8238
# Epoch 288/1000
# 14/14 [==============================] - 3s 183ms/step - loss: 1.3485 - val_loss: 2.7967
# Epoch 289/1000
# 14/14 [==============================] - 3s 211ms/step - loss: 1.2907 - val_loss: 2.5440
# Epoch 290/1000
# 14/14 [==============================] - 3s 209ms/step - loss: 1.3111 - val_loss: 2.8914
# Epoch 291/1000
# 14/14 [==============================] - 3s 202ms/step - loss: 1.4538 - val_loss: 2.1174
# Epoch 292/1000
# 14/14 [==============================] - 3s 189ms/step - loss: 1.3517 - val_loss: 1.8361
# Epoch 293/1000
# 14/14 [==============================] - 3s 187ms/step - loss: 1.3677 - val_loss: 1.9909
# Epoch 294/1000
# 14/14 [==============================] - 3s 191ms/step - loss: 1.3904 - val_loss: 2.4092
# Epoch 295/1000
# 14/14 [==============================] - 3s 212ms/step - loss: 1.2588 - val_loss: 2.5181
# Epoch 296/1000
# 14/14 [==============================] - 3s 200ms/step - loss: 1.3406 - val_loss: 2.4930
# Epoch 297/1000
# 14/14 [==============================] - 3s 197ms/step - loss: 1.2704 - val_loss: 1.9458
# Epoch 298/1000
# 14/14 [==============================] - 3s 193ms/step - loss: 1.3955 - val_loss: 1.7933
# Epoch 299/1000
# 14/14 [==============================] - 3s 201ms/step - loss: 1.3548 - val_loss: 2.1829
# Epoch 300/1000
# 14/14 [==============================] - 3s 206ms/step - loss: 1.3891 - val_loss: 2.1094
# Epoch 301/1000
# 14/14 [==============================] - 3s 211ms/step - loss: 1.3305 - val_loss: 1.9652
# Epoch 302/1000
# 14/14 [==============================] - 3s 206ms/step - loss: 1.2688 - val_loss: 1.8394
# Epoch 303/1000
# 14/14 [==============================] - 3s 204ms/step - loss: 1.2692 - val_loss: 1.7405
# Epoch 304/1000
# 14/14 [==============================] - 3s 203ms/step - loss: 1.2511 - val_loss: 1.6229
# Epoch 305/1000
# 14/14 [==============================] - 3s 205ms/step - loss: 1.3027 - val_loss: 1.5357
# Epoch 306/1000
# 14/14 [==============================] - 3s 211ms/step - loss: 1.2205 - val_loss: 1.4987
# Epoch 307/1000
# 14/14 [==============================] - 3s 201ms/step - loss: 1.3209 - val_loss: 1.4639
# Epoch 308/1000
# 14/14 [==============================] - 3s 197ms/step - loss: 1.2936 - val_loss: 1.4042
# Epoch 309/1000
# 14/14 [==============================] - 3s 189ms/step - loss: 1.3374 - val_loss: 1.3799
# Epoch 310/1000
# 14/14 [==============================] - 3s 204ms/step - loss: 1.2503 - val_loss: 1.3712
# Epoch 311/1000
# 14/14 [==============================] - 3s 181ms/step - loss: 1.3225 - val_loss: 1.3186
# Epoch 312/1000
# 14/14 [==============================] - 2s 179ms/step - loss: 1.2913 - val_loss: 1.3101
# Epoch 313/1000
# 14/14 [==============================] - 3s 185ms/step - loss: 1.2364 - val_loss: 1.2727
# Epoch 314/1000
# 14/14 [==============================] - 3s 193ms/step - loss: 1.2525 - val_loss: 1.2577
# Epoch 315/1000
# 14/14 [==============================] - 2s 174ms/step - loss: 1.2310 - val_loss: 1.2673
# Epoch 316/1000
# 14/14 [==============================] - 3s 201ms/step - loss: 1.2487 - val_loss: 1.2626
# Epoch 317/1000
# 14/14 [==============================] - 3s 200ms/step - loss: 1.2616 - val_loss: 1.2635
# Epoch 318/1000
# 14/14 [==============================] - 3s 204ms/step - loss: 1.2675 - val_loss: 1.2759
# Epoch 319/1000
# 14/14 [==============================] - 3s 206ms/step - loss: 1.2060 - val_loss: 1.2694
# Epoch 320/1000
# 14/14 [==============================] - 3s 204ms/step - loss: 1.2824 - val_loss: 1.2606
# Epoch 321/1000
# 14/14 [==============================] - 3s 213ms/step - loss: 1.2820 - val_loss: 1.2556
# Epoch 322/1000
# 14/14 [==============================] - 3s 190ms/step - loss: 1.1991 - val_loss: 1.2372
# Epoch 323/1000
# 14/14 [==============================] - 3s 184ms/step - loss: 1.2368 - val_loss: 1.2428
# Epoch 324/1000
# 14/14 [==============================] - 3s 218ms/step - loss: 1.4350 - val_loss: 1.2382
# Epoch 325/1000
# 14/14 [==============================] - 3s 184ms/step - loss: 1.2565 - val_loss: 1.2391
# Epoch 326/1000
# 14/14 [==============================] - 3s 189ms/step - loss: 1.2080 - val_loss: 1.2392
# Epoch 327/1000
# 14/14 [==============================] - 2s 171ms/step - loss: 1.3613 - val_loss: 1.2610
# Epoch 328/1000
# Epoch 361/1000
# 14/14 [==============================] - 3s 210ms/step - loss: 1.2029 - val_loss: 1.2468
# Epoch 362/1000
# 14/14 [==============================] - 3s 194ms/step - loss: 1.2934 - val_loss: 1.2578
# Epoch 363/1000
# 14/14 [==============================] - 3s 191ms/step - loss: 1.1978 - val_loss: 1.2536
# Epoch 364/1000
# 14/14 [==============================] - 3s 183ms/step - loss: 1.2201 - val_loss: 1.2483
# Epoch 365/1000
# 14/14 [==============================] - 3s 184ms/step - loss: 1.1850 - val_loss: 1.2513
# Epoch 366/1000
# 14/14 [==============================] - 3s 200ms/step - loss: 1.2327 - val_loss: 1.2513
# Epoch 367/1000
# 14/14 [==============================] - 3s 206ms/step - loss: 1.2448 - val_loss: 1.2515
# Epoch 368/1000
# 14/14 [==============================] - 3s 205ms/step - loss: 1.2430 - val_loss: 1.2944
# Epoch 369/1000
# 14/14 [==============================] - 3s 201ms/step - loss: 1.2740 - val_loss: 1.3460
# Epoch 370/1000
# 14/14 [==============================] - 3s 208ms/step - loss: 1.2375 - val_loss: 1.3470
# Epoch 371/1000
# 14/14 [==============================] - 3s 190ms/step - loss: 1.2968 - val_loss: 1.2906
# C:\Users\cai-sh\anaconda3\envs\wc_ratio\lib\site-packages\keras\utils\generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
### Plot the Loss graph

if train_mode == True:
    plt.subplots(figsize=(6,4.5))
    plt.plot(history.history['loss'],'b-',label='train_loss')
    plt.plot(history.history['val_loss'],'b-',label='val_loss',color='r')

    plt.legend(prop={'size': 20})

    plt.xlabel("Epoch", fontdict={'size': 20})
    plt.ylabel("Loss", fontdict={'size': 20})

    plt.xticks((0, 200, 400, 600, 800, 1000),fontsize=15)
    plt.yticks(fontsize=15)

    plt.grid(True)
    plt.show()

# %%
### Print the prediction results

test_losses = []
p_result_0 = []

# Load Model & Make Results
model.load_weights(last_model_save_dir)
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam())

test_losses = model.evaluate(x_test, y_test, verbose=0)
p_result_0 = model.predict(x_test)

p_result_0
# Out:
# array([[60.130356],
#        [55.05354 ],
#        [49.399094],
#        ...,
#        [40.04547 ],
#        [48.99354 ],
#        [54.953686]], dtype=float32)

# %%
### print RMSE and R2-score

rmse_0 = round(mean_squared_error(y_test, p_result_0, squared=False), 4)
r2_0 = round(r2_score(y_test, p_result_0), 4)

print(f"RMSE : {rmse_0}")
print(f"r2_score : {r2_0}")
# Out:
# RMSE : 1.1204
# r2_score : 0.9701

# %%
# Preprocess the results (group by the same y-value).
p_list_0 = [[]for i in range(len(WC_name_tag))]

for i,test_water in enumerate(y_test):    
    for j,wc_name in enumerate(WC_name_tag):
        
        if i==len(y_test):
            break
            
        # If the actual water-cement ratio and the estimated water-cement ratio are the same, append to p_list.
        if(np.round(test_water,3)==wc_name):
            p_list_0[j].append(p_result_0[i])
         
p_list_0
# Out:
# [[array([39.989193], dtype=float32),
#   array([40.449078], dtype=float32),
#   array([40.032772], dtype=float32),
#   array([39.883785], dtype=float32),
#   array([40.084923], dtype=float32),
#   array([39.85681], dtype=float32),
#   array([45.091885], dtype=float32),
#   array([45.759468], dtype=float32),
#   array([44.73813], dtype=float32),
#   array([45.338665], dtype=float32),
#   array([45.570713], dtype=float32),
#   array([45.11851], dtype=float32),
#   array([44.909695], dtype=float32),
#   array([45.875835], dtype=float32),
#   array([45.464993], dtype=float32),
#   array([44.497215], dtype=float32),
#   array([44.635822], dtype=float32),
#   array([44.652725], dtype=float32),
#   array([45.491695], dtype=float32),
#   array([44.974384], dtype=float32),
#   array([45.023792], dtype=float32),
#   array([45.638195], dtype=float32),
#   array([43.345043], dtype=float32),
#   array([45.956455], dtype=float32),
#   array([46.315647], dtype=float32),
#   array([45.88526], dtype=float32),
#   array([45.057297], dtype=float32),
#   array([48.090504], dtype=float32),
#   array([44.689335], dtype=float32),
#   array([44.60598], dtype=float32),
#   array([44.188175], dtype=float32),
#   array([46.408916], dtype=float32),
#   array([45.931873], dtype=float32),
#   array([46.465343], dtype=float32),
#   array([45.193035], dtype=float32),
#   array([46.00833], dtype=float32),
#   array([46.560604], dtype=float32),
#   array([46.264553], dtype=float32),
#   array([43.356087], dtype=float32),
#   array([45.45537], dtype=float32),
#   array([45.138535], dtype=float32),
#   array([46.514774], dtype=float32),
#   array([44.9755], dtype=float32),
#   array([46.05453], dtype=float32),
#   array([44.218433], dtype=float32),
#   array([42.710896], dtype=float32),
#   array([45.86085], dtype=float32),
#   array([47.38055], dtype=float32),
#   array([43.053226], dtype=float32),
#   array([45.347404], dtype=float32),
#   array([45.971325], dtype=float32),
#   array([45.67474], dtype=float32),
#   array([44.70716], dtype=float32),
#   array([46.56154], dtype=float32),
#   array([46.092876], dtype=float32),
#   array([45.556904], dtype=float32),
#   array([46.312794], dtype=float32),
#   array([45.16765], dtype=float32),
#   array([46.246227], dtype=float32),
#   array([45.29112], dtype=float32),
#   array([45.818443], dtype=float32),
#   array([45.704945], dtype=float32),
#   array([46.433735], dtype=float32),
# ...
#   array([59.96903], dtype=float32),
#   array([60.113976], dtype=float32),
#   array([59.289753], dtype=float32),
#   array([60.075085], dtype=float32),
#   array([60.153843], dtype=float32),
#   array([59.933342], dtype=float32),
#   array([60.108887], dtype=float32),
#   array([59.9556], dtype=float32),
#   array([59.965954], dtype=float32),
#   array([59.81243], dtype=float32),
#   array([60.03316], dtype=float32),
#   array([60.054127], dtype=float32),
#   array([60.139088], dtype=float32),
#   array([60.062996], dtype=float32),
#   array([59.81999], dtype=float32),
#   array([59.543392], dtype=float32),
#   array([59.951168], dtype=float32),
#   array([59.85789], dtype=float32),
#   array([60.103695], dtype=float32),
#   array([59.907654], dtype=float32),
#   array([60.001266], dtype=float32),
#   array([60.014305], dtype=float32),
#   array([59.98234], dtype=float32),
#   array([59.98997], dtype=float32),
#   array([59.98424], dtype=float32),
#   array([60.03652], dtype=float32),
#   array([59.923527], dtype=float32),
#   array([59.93398], dtype=float32),
#   array([60.030293], dtype=float32),
#   array([59.991203], dtype=float32),
#   array([59.954597], dtype=float32),
#   array([60.215237], dtype=float32),
#   array([60.12209], dtype=float32),
#   array([57.907227], dtype=float32),
#   array([59.95886], dtype=float32),
#   array([60.054127], dtype=float32),
#   array([60.038895], dtype=float32),
#   array([60.121906], dtype=float32),
#   array([59.926006], dtype=float32),
#   array([59.989223], dtype=float32),
#   array([60.04002], dtype=float32),
#   array([59.945618], dtype=float32),
#   array([58.948254], dtype=float32),
#   array([60.06554], dtype=float32),
#   array([60.054127], dtype=float32),
#   array([60.079586], dtype=float32),
#   array([60.25238], dtype=float32),
#   array([60.02155], dtype=float32),
#   array([59.966293], dtype=float32),
#   array([60.005604], dtype=float32),
#   array([60.109673], dtype=float32),
#   array([60.005604], dtype=float32),
#   array([60.000477], dtype=float32),
#   array([59.997128], dtype=float32),
#   array([60.09102], dtype=float32),
#   array([59.996037], dtype=float32),
#   array([59.89315], dtype=float32),
#   array([59.85796], dtype=float32),
#   array([60.008995], dtype=float32),
#   array([59.95372], dtype=float32),
#   array([59.894604], dtype=float32),
#   array([60.054127], dtype=float32),
#   array([60.022533], dtype=float32),
#   array([60.115276], dtype=float32),
#   array([59.754776], dtype=float32),
#   array([60.039368], dtype=float32),
#   array([59.92697], dtype=float32),
#   array([59.905537], dtype=float32),
#   array([59.956844], dtype=float32),
#   array([60.005604], dtype=float32),
#   array([60.086857], dtype=float32),
#   array([59.81046], dtype=float32),
#   array([60.00221], dtype=float32),
#   array([59.919807], dtype=float32),
#   array([59.95892], dtype=float32),
#   array([59.853428], dtype=float32),
#   array([59.99058], dtype=float32),
#   array([60.06005], dtype=float32),
#   array([60.13832], dtype=float32),
#   array([59.91537], dtype=float32),
#   array([60.012592], dtype=float32),
#   array([60.083775], dtype=float32),
#   array([59.960056], dtype=float32),
#   array([60.01592], dtype=float32),
#   array([59.8884], dtype=float32),
#   array([59.92638], dtype=float32),
#   array([60.062397], dtype=float32),
#   array([59.260025], dtype=float32),
#   array([59.921535], dtype=float32),
#   array([60.13227], dtype=float32),
#   array([59.918327], dtype=float32),
#   array([59.958828], dtype=float32),
#   array([60.01656], dtype=float32),
#   array([59.90752], dtype=float32),
#   array([60.01656], dtype=float32),
#   array([60.02503], dtype=float32),
#   array([59.964046], dtype=float32),
#   array([59.954502], dtype=float32),
#   array([59.853428], dtype=float32),
#   array([60.081802], dtype=float32),
#   array([59.8673], dtype=float32),
#   array([59.990036], dtype=float32),
#   array([60.10954], dtype=float32),
#   array([60.046543], dtype=float32),
#   array([59.99316], dtype=float32),
#   array([60.21737], dtype=float32),
#   array([60.015602], dtype=float32),
#   array([60.001266], dtype=float32),
#   array([60.113354], dtype=float32),
#   array([60.012024], dtype=float32),
#   array([59.94593], dtype=float32),
#   array([60.02503], dtype=float32),
#   array([59.990086], dtype=float32),
#   array([59.940044], dtype=float32),
#   array([60.0952], dtype=float32),
#   array([60.200756], dtype=float32),
#   array([60.02656], dtype=float32),
#   array([60.10969], dtype=float32),
#   array([59.937664], dtype=float32),
#   array([60.005604], dtype=float32),
#   array([59.839314], dtype=float32),
#   array([60.006336], dtype=float32),
#   array([60.126118], dtype=float32),
#   array([59.987476], dtype=float32),
#   array([60.035305], dtype=float32),
#   array([60.034443], dtype=float32),
#   array([60.231358], dtype=float32),
#   array([60.127804], dtype=float32),
#   array([59.94454], dtype=float32),
#   array([60.09555], dtype=float32),
#   array([59.94682], dtype=float32),
#   array([59.82418], dtype=float32),
#   array([59.85861], dtype=float32),
#   array([59.814327], dtype=float32),
#   array([60.004986], dtype=float32),
#   array([60.039368], dtype=float32),
#   array([60.138058], dtype=float32),
#   array([60.077587], dtype=float32),
#   array([59.885967], dtype=float32),
#   array([59.679256], dtype=float32),
#   array([59.986156], dtype=float32),
#   array([59.95758], dtype=float32),
#   array([60.005604], dtype=float32),
#   array([59.951916], dtype=float32),
#   array([60.019806], dtype=float32),
#   array([59.940132], dtype=float32),
#   array([59.148083], dtype=float32),
#   array([60.035213], dtype=float32),
#   array([59.97277], dtype=float32),
#   array([60.065495], dtype=float32),
#   array([60.044262], dtype=float32),
#   array([59.958126], dtype=float32),
#   array([59.86562], dtype=float32),
#   array([60.10482], dtype=float32),
#   array([59.999912], dtype=float32),
#   array([59.69334], dtype=float32),
#   array([60.021275], dtype=float32),
#   array([59.874184], dtype=float32),
#   array([60.070824], dtype=float32),
#   array([60.001266], dtype=float32),
#   array([60.025055], dtype=float32),
#   array([59.85801], dtype=float32),
#   array([60.135643], dtype=float32),
#   array([59.98997], dtype=float32),
#   array([60.044735], dtype=float32),
#   array([60.113056], dtype=float32),
#   array([60.051754], dtype=float32),
#   array([59.944546], dtype=float32),
#   array([59.956554], dtype=float32),
#   array([59.858097], dtype=float32),
#   array([60.037327], dtype=float32),
#   array([60.07067], dtype=float32),
#   array([60.03101], dtype=float32),
#   array([59.71832], dtype=float32),
#   array([59.92744], dtype=float32),
#   array([60.009216], dtype=float32),
#   array([59.961605], dtype=float32),
#   array([59.51441], dtype=float32),
#   array([60.07256], dtype=float32),
#   array([60.051876], dtype=float32),
#   array([59.889297], dtype=float32),
#   array([60.001923], dtype=float32),
#   array([60.06577], dtype=float32),
#   array([59.78595], dtype=float32),
#   array([60.070644], dtype=float32),
#   array([60.083088], dtype=float32),
#   array([60.02076], dtype=float32),
#   array([59.894985], dtype=float32),
#   array([60.09929], dtype=float32),
#   array([60.012768], dtype=float32),
#   array([60.08057], dtype=float32),
#   array([46.795555], dtype=float32),
#   array([60.165165], dtype=float32),
#   array([60.070293], dtype=float32),
#   array([60.005604], dtype=float32),
#   array([60.054127], dtype=float32),
#   array([60.04002], dtype=float32),
#   array([60.09476], dtype=float32),
#   array([59.93603], dtype=float32),
#   array([60.050117], dtype=float32),
#   array([60.029095], dtype=float32),
#   array([60.129288], dtype=float32),
#   array([59.953403], dtype=float32),
#   array([60.03568], dtype=float32),
#   array([59.864124], dtype=float32),
#   array([59.632114], dtype=float32),
#   array([60.014305], dtype=float32),
#   array([60.07793], dtype=float32),
#   array([60.0078], dtype=float32),
#   array([60.08566], dtype=float32),
#   array([60.054127], dtype=float32),
#   array([60.02003], dtype=float32),
#   array([59.945004], dtype=float32),
#   array([59.972595], dtype=float32),
#   array([60.04114], dtype=float32),
#   array([60.077587], dtype=float32),
#   array([59.945614], dtype=float32),
#   array([60.02087], dtype=float32),
#   array([59.910072], dtype=float32),
#   array([59.89867], dtype=float32),
#   array([60.07601], dtype=float32),
#   array([59.91537], dtype=float32),
#   array([59.74954], dtype=float32),
#   array([59.859097], dtype=float32),
#   array([59.919807], dtype=float32),
#   array([60.14934], dtype=float32),
#   array([59.754776], dtype=float32),
#   array([60.027645], dtype=float32),
#   array([60.124638], dtype=float32),
#   array([60.038223], dtype=float32),
#   array([60.07856], dtype=float32),
#   array([60.25238], dtype=float32),
#   array([59.743237], dtype=float32),
#   array([60.12853], dtype=float32),
#   array([60.064148], dtype=float32),
#   array([60.03877], dtype=float32),
#   array([59.87665], dtype=float32),
#   array([60.01656], dtype=float32),
#   array([60.07757], dtype=float32),
#   array([60.090996], dtype=float32),
#   array([60.047398], dtype=float32),
#   array([60.001637], dtype=float32),
#   array([59.878426], dtype=float32),
#   array([59.923103], dtype=float32),
#   array([60.031303], dtype=float32),
#   array([59.950977], dtype=float32),
#   array([59.961784], dtype=float32),
#   array([60.040817], dtype=float32),
#   array([59.877552], dtype=float32),
#   array([59.463596], dtype=float32),
#   array([59.21976], dtype=float32),
#   array([59.966595], dtype=float32),
#   array([60.03109], dtype=float32),
#   array([60.077587], dtype=float32),
#   array([59.934544], dtype=float32),
#   array([60.083088], dtype=float32),
#   array([60.163662], dtype=float32),
#   array([60.035774], dtype=float32),
#   array([60.00106], dtype=float32),
#   array([60.11473], dtype=float32),
#   array([59.931545], dtype=float32),
#   array([60.001186], dtype=float32),
#   array([60.009216], dtype=float32),
#   array([59.860126], dtype=float32),
#   array([59.942345], dtype=float32),
#   array([60.137516], dtype=float32),
#   array([60.12576], dtype=float32),
#   array([60.005604], dtype=float32),
#   array([58.981495], dtype=float32),
#   array([59.92853], dtype=float32),
#   array([60.219482], dtype=float32),
#   array([59.966343], dtype=float32),
#   array([60.092743], dtype=float32),
#   array([59.915646], dtype=float32),
#   array([60.03726], dtype=float32),
#   array([60.04115], dtype=float32),
#   array([59.88959], dtype=float32),
#   array([60.01923], dtype=float32),
#   array([59.613262], dtype=float32),
#   array([59.932552], dtype=float32),
#   array([59.90864], dtype=float32),
#   array([60.108208], dtype=float32),
#   array([60.186584], dtype=float32),
#   array([59.869648], dtype=float32),
#   array([59.934925], dtype=float32),
#   array([59.797527], dtype=float32),
#   array([60.02503], dtype=float32),
#   array([60.1908], dtype=float32),
#   array([60.044147], dtype=float32),
#   array([60.056942], dtype=float32),
#   array([59.919807], dtype=float32),
#   array([59.93812], dtype=float32),
#   array([59.920143], dtype=float32),
#   array([60.0036], dtype=float32),
#   array([59.93431], dtype=float32),
#   array([60.03342], dtype=float32),
#   array([60.013412], dtype=float32),
#   array([59.92858], dtype=float32),
#   array([60.009216], dtype=float32),
#   array([59.890915], dtype=float32),
#   array([60.03316], dtype=float32),
#   array([59.928963], dtype=float32),
#   array([60.12853], dtype=float32),
#   array([58.921154], dtype=float32),
#   array([60.083164], dtype=float32),
#   array([59.87259], dtype=float32),
#   array([60.005604], dtype=float32),
#   array([59.919807], dtype=float32),
#   array([59.949005], dtype=float32),
#   array([60.009007], dtype=float32),
#   array([60.131382], dtype=float32),
#   array([60.03316], dtype=float32),
#   array([60.071968], dtype=float32),
#   array([59.94682], dtype=float32),
#   array([60.14356], dtype=float32),
#   array([59.80971], dtype=float32),
#   array([60.127804], dtype=float32),
#   array([59.96117], dtype=float32),
#   array([60.03688], dtype=float32),
#   array([60.003407], dtype=float32),
#   array([60.03329], dtype=float32),
#   array([59.87665], dtype=float32),
#   array([60.00194], dtype=float32),
#   array([59.91513], dtype=float32),
#   array([59.872997], dtype=float32),
#   array([59.862606], dtype=float32),
#   array([59.91609], dtype=float32),
#   array([60.00194], dtype=float32),
#   array([60.005604], dtype=float32),
#   array([60.199154], dtype=float32),
#   array([60.241714], dtype=float32),
#   array([60.022533], dtype=float32),
#   array([59.896854], dtype=float32),
#   array([59.83793], dtype=float32),
#   array([59.955532], dtype=float32),
#   array([59.996544], dtype=float32),
#   array([59.94592], dtype=float32),
#   array([60.053898], dtype=float32),
#   array([60.024826], dtype=float32),
#   array([60.034443], dtype=float32),
#   array([59.943523], dtype=float32),
#   array([60.054127], dtype=float32),
#   array([60.07385], dtype=float32),
#   array([60.009216], dtype=float32),
#   array([59.96323], dtype=float32),
#   array([59.922676], dtype=float32),
#   array([60.039368], dtype=float32),
#   array([59.913357], dtype=float32),
#   array([60.004307], dtype=float32),
#   array([59.942867], dtype=float32),
#   array([59.87747], dtype=float32),
#   array([59.85697], dtype=float32),
#   array([59.874706], dtype=float32),
#   array([59.990036], dtype=float32),
#   array([60.02229], dtype=float32),
#   array([60.034443], dtype=float32),
#   array([60.005604], dtype=float32),
#   array([59.95267], dtype=float32),
#   array([59.934475], dtype=float32),
#   array([60.005604], dtype=float32),
#   array([59.958126], dtype=float32),
#   array([60.177433], dtype=float32),
#   array([59.584953], dtype=float32),
#   array([60.041553], dtype=float32),
#   array([60.17294], dtype=float32),
#   array([59.98099], dtype=float32),
#   array([60.07067], dtype=float32),
#   array([60.000477], dtype=float32),
#   array([60.04984], dtype=float32),
#   array([59.913357], dtype=float32),
#   array([60.033867], dtype=float32),
#   array([59.930187], dtype=float32),
#   array([59.89315], dtype=float32),
#   array([59.99967], dtype=float32),
#   array([60.101162], dtype=float32),
#   array([59.808804], dtype=float32),
#   array([60.05354], dtype=float32),
#   array([59.986843], dtype=float32),
#   array([60.10124], dtype=float32),
#   array([60.07896], dtype=float32),
#   array([59.853428], dtype=float32),
#   array([60.0166], dtype=float32),
#   array([60.034443], dtype=float32),
#   array([59.91096], dtype=float32),
#   array([60.446823], dtype=float32),
#   array([59.91537], dtype=float32),
#   array([59.919807], dtype=float32),
#   array([59.95389], dtype=float32),
#   array([59.869648], dtype=float32),
#   array([60.14253], dtype=float32),
#   array([60.04433], dtype=float32),
#   array([60.1358], dtype=float32),
#   array([60.10857], dtype=float32),
#   array([60.05968], dtype=float32),
#   array([59.859707], dtype=float32),
#   array([60.001423], dtype=float32),
#   array([59.94182], dtype=float32),
#   array([60.01383], dtype=float32),
#   array([60.07184], dtype=float32),
#   array([59.92258], dtype=float32),
#   array([59.950706], dtype=float32),
#   array([60.10482], dtype=float32),
#   array([59.927555], dtype=float32),
#   array([59.754776], dtype=float32),
#   array([59.999218], dtype=float32),
#   array([59.95164], dtype=float32),
#   array([60.00187], dtype=float32),
#   array([59.957855], dtype=float32),
#   array([59.93923], dtype=float32),
#   array([60.092743], dtype=float32),
#   array([60.00106], dtype=float32),
#   array([59.85138], dtype=float32),
#   array([60.12801], dtype=float32),
#   array([60.083336], dtype=float32),
#   array([60.043198], dtype=float32),
#   array([60.07814], dtype=float32),
#   array([60.04984], dtype=float32),
#   array([60.003223], dtype=float32),
#   array([60.054127], dtype=float32),
#   array([60.095234], dtype=float32),
#   array([60.007534], dtype=float32),
#   array([59.551704], dtype=float32),
#   array([59.998997], dtype=float32),
#   array([59.851063], dtype=float32),
#   array([59.945713], dtype=float32),
#   array([60.018932], dtype=float32),
#   array([59.764603], dtype=float32),
#   array([60.07256], dtype=float32),
#   array([60.05617], dtype=float32),
#   array([59.853428], dtype=float32),
#   array([59.89094], dtype=float32),
#   array([60.007664], dtype=float32),
#   array([59.966293], dtype=float32),
#   array([60.024826], dtype=float32),
#   array([59.89295], dtype=float32),
#   array([59.807533], dtype=float32),
#   array([60.029095], dtype=float32)]]

# %%
### Print the mean and standard deviation of the predicted WCR (Water-Cement Ratio).

p_list_mean = [[]for i in range(len(WC_name_tag))]
p_list_std = [[]for i in range(len(WC_name_tag))]

for i in range(len(WC_name_tag)):
    tmp_mean = np.mean(p_list_0[i])
    tmp_std = np.std(p_list_0[i])
    
    p_list_mean[i].append(tmp_mean)
    p_list_std[i].append(tmp_std)

flattened_mean = [item for sublist in p_list_mean for item in sublist]
flattened_std = [item for sublist in p_list_std for item in sublist]

print(f"mean per WCR: {flattened_mean}\n")
print(f"std per WCR: {flattened_std}")
# Out:
# mean per WCR: [40.24372, 43.138767, 45.36283, 46.888344, 49.80865, 52.334366, 54.623142, 57.377853, 59.94797]
#
# std per WCR: [0.91099703, 1.2616262, 1.1787416, 1.0679761, 1.2558907, 1.3829621, 0.94599456, 0.6058907, 0.62336195]

# %%
### Plot graph

x_axis = [40, 42.5, 45, 47.5, 50, 52.5, 55, 57.5, 60]
y_axis = [37.5, 40, 42.5, 45, 47.5, 50, 52.5, 55, 57.5, 60, 62.5]
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:olive', 'tab:cyan']

fig, ax = plt.subplots(figsize=(6, 6))

for i, tmp_color in enumerate(colors):
    ax.errorbar(WC_name_tag[i], flattened_mean[i], yerr=flattened_std[i], linestyle='None', markeredgecolor='k', ecolor='k', marker='o', markersize=7.5, color=tmp_color, capsize=5, elinewidth=1.5)

# equal line
plt.plot([40, 42.5, 45, 47.5, 50, 52.5, 55, 57.5, 60], [40, 42.5, 45, 47.5, 50, 52.5, 55, 57.5, 60], c='k', ls='--', lw=1, label='Equality line')

# upper line
plt.plot([40, 42.5, 45, 47.5, 50, 52.5, 55, 57.5, 60], [42, 44.5, 47, 49.5, 52, 54.5, 57, 59.5, 62], c='k', ls='--', lw=0.5, label='±2% line')

# under lone
plt.plot([40, 42.5, 45, 47.5, 50, 52.5, 55, 57.5, 60], [38, 40.5, 43, 45.5, 48, 50.5, 53, 55.5, 58], c='k', ls='--', lw=0.5)

plt.xlabel('Actual w/c ratio (%)', fontdict={'size': 20})
plt.ylabel('Estimated w/c ratio (%)', fontdict={'size': 20})
plt.xticks(x_axis, fontsize=15)
plt.yticks(y_axis, fontsize=15)
plt.legend(fontsize=14)

plt.show()
